# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import random
import joblib
import numpy as np
import pandas as pd
import numpy as np
import tensorflow as tf
import functools, operator
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/MP/data.csv')
df

# %%
videoIDs = list(df.VideoID.unique())
print(len(videoIDs))

# %%
# !tar -xvf  '/content/drive/MyDrive/MP/YouTubeClips.tar'

# %%
def extract_frames_equally_spaced(frames,sel):
        n_frames = len(frames)
        sub_frames = []

        for idx in n_frames:
          if(sel[idx]=='1'):
            sub_frames.append(frames[idx])
        return sub_frames

def extract_frames_sampled(frames, K):
        n_frames = len(frames)
        splits = [i  for i in range(0,n_frames,14)]
#         print(splits)
        sub_frames = []

        for idx in splits:
          sub_frames.append(frames[idx])
        return sub_frames

def pad_frames(frames, limit, jpegs=False):
        last_frame = frames[-1]
        if jpegs:
            frames_padded = frames + [last_frame]*(limit-len(frames))
        else:
            padding = np.asarray([last_frame * 0.]*(limit-len(frames)))
            frames_padded = np.concatenate([frames, padding], axis=0)
        return frames_padded

def video_to_frames(input_loc,K,sel,motion=False):
    cap = cv2.VideoCapture(input_loc)
    
    video_length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) - 1
    count = 0

    if motion is True:
      K = max(video_length,50)

    frames=[]
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            continue
        frames.append(frame)
        count = count + 1
        
        if (count > (video_length-1)):
            cap.release()
            break
    if len(frames) < K:
        frames = pad_frames(frames,K,True)
    # else:
    #     frames = extract_frames_equally_spaced(frames,K,sel)
    
    return frames

def resize_frames(frames):
  new_frames = []
  for frame in frames:
    new_frame = cv2.resize(frame,(224,224))
    new_frames.append(new_frame)
  
  return new_frames

K=28

# %%
#Googlenet model
def get_model():
  i = tf.keras.layers.Input([224, 224, 3], dtype = tf.float32)
  x = tf.keras.applications.inception_v3.preprocess_input(i)
  model = InceptionV3(weights="imagenet", include_top=False, input_shape=(224, 224, 3),pooling='avg')
  out = model(x)
  model=tf.keras.models.Model(inputs=[i], outputs=out)
  return model
  # model.summary()

# %%
# !pip install sk-video
# !wget -O 'c3d.py' 'https://drive.google.com/uc?id=1RC9trsgIo2OsM8dV7CPg73drqSRZMr8j&confirm=t'
# !wget -O 'sports1M_utils.py' 'https://drive.google.com/uc?id=1S49OSW2pCUPPD9F-763mG-aBx2gBOr2i&confirm=t'

# %%
# Extracting Motion Features
import skvideo.io
import importlib as imp
from c3d import C3D
from keras.models import Model
import sports1M_utils
imp.reload(sports1M_utils)

def extract_motion_features(save=False):
  if not os.path.exists('motion_features1'):
    os.makedirs('motion_features1')

  base_model = C3D(weights='sports1M')
  model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc6').output)

  for index, id in enumerate(videoIDs[1600:]):
    path = 'drive/MyDrive/IT416/YouTubeClips/'
    path+=id
    path+='.avi'


    frames = video_to_frames(path,K,True)
    frames = resize_frames(frames)
    frames = np.array(frames)

    windows = []
    org_vid = frames
    vid = []
    motion_features_video = []
    for i in range(len(frames)):
      vid.append(frames[i])
      if i==15:
        windows.append(vid)
      elif i>=16:
        vid.pop(0)
        windows.append(vid)
        
    windows = extract_frames_equally_spaced(windows,28)
    for window in windows:
      x = sports1M_utils.preprocess_input(np.array(window))
      feature_vector = model.predict(x) 
      feature_vector = feature_vector[0]
      feature_vector = np.array(feature_vector)

      motion_features_video.append(feature_vector)
    motion_features_video = np.array(motion_features_video)
    
    path='motion_features1/'+id+'.npy'
    np.save(path, motion_features_video)

    if index%200==0 and index>0:
      # !zip -r motion_features1.zip motion_features1
      # !cp 'motion_features1.zip' 'drive/MyDrive/IT416/'
    print(index,':',motion_features_video.shape)

  if save is True:
    # !zip -r motion_features1.zip motion_features1
    # !cp 'motion_features1.zip' 'drive/MyDrive/IT416/'

# %%
extract_motion_features(save=True)

# %%
# !unzip '/content/drive/MyDrive/MP/Gloabal_GA_Features.zip'
# Out:
# Archive:  /content/drive/MyDrive/MP/Gloabal_GA_Features.zip
#   inflating: -4wsuPCjDBc_5_15.npy
#   inflating: -7KMZQEsJW4_205_208.npy
#   inflating: -8y1Q0rA3n8_108_115.npy
#   inflating: -8y1Q0rA3n8_95_102.npy
#   inflating: -9CUm-2cui8_39_44.npy
#   inflating: -AwoiGR6c8M_10_14.npy
#   inflating: -Cv5LsqKUXc_17_25.npy
#   inflating: -Cv5LsqKUXc_71_76.npy
#   inflating: -DKuLXYoY3g_14_20.npy
#   inflating: -DRy7rBg0IQ_31_37.npy
#   inflating: -FugkxLmGO4_5_16.npy
#   inflating: -Ms9tsWmhyU_80_95.npy
#   inflating: -YI0cxuNcq8_262_272.npy
#   inflating: -_aaMGK6GGw_57_61.npy
#   inflating: -_hbPLsZvvo_172_179.npy
#   inflating: -_hbPLsZvvo_18_25.npy
#   inflating: -_hbPLsZvvo_19_25.npy
#   inflating: -_hbPLsZvvo_19_26.npy
#   inflating: -_hbPLsZvvo_211_219.npy
#   inflating: -_hbPLsZvvo_269_275.npy
#   inflating: -_hbPLsZvvo_288_305.npy
#   inflating: -_hbPLsZvvo_323_328.npy
#   inflating: -_hbPLsZvvo_43_55.npy
#   inflating: -_hbPLsZvvo_49_55.npy
#   inflating: -_hbPLsZvvo_5_8.npy
#   inflating: -bjOB4zS0uE_100_105.npy
#   inflating: -dm-ds5rRaM_44_52.npy
#   inflating: -joBOHlg5J0_72_80.npy
#   inflating: -mAoVOhKy0c_4_9.npy
#   inflating: -pUwIypksfE_13_23.npy
#   inflating: -rkErLY0rRc_26_35.npy
#   inflating: -rkErLY0rRc_63_67.npy
#   inflating: -rvjK0lE3z4_33_43.npy
#   inflating: -s4-6QTT7HE_235_241.npy
#   inflating: -t-ZWaJeH-o_0_15.npy
#   inflating: -uT_1VDvXok_8_15.npy
#   inflating: -vKO3uSG6Do_3_14.npy
#   inflating: -vg3vR86fu0_1_6.npy
#   inflating: -wa0umYJVGg_100_115.npy
#   inflating: -wa0umYJVGg_117_123.npy
#   inflating: -wa0umYJVGg_139_157.npy
#   inflating: -wa0umYJVGg_168_176.npy
#   inflating: -wa0umYJVGg_23_41.npy
#   inflating: -wa0umYJVGg_271_276.npy
#   inflating: -wa0umYJVGg_286_290.npy
#   inflating: -zOrV-5vh1A_69_76.npy
#   inflating: 00jrXRMlZOY_0_10.npy
#   inflating: 02Z-kuB3IaM_2_13.npy
#   inflating: 04Gt01vatkk_248_265.npy
#   inflating: 04Gt01vatkk_308_321.npy
#   inflating: 05Gtb7_9tLU_0_9.npy
#   inflating: 05gNigkqfNU_11_23.npy
#   inflating: 05gNigkqfNU_24_32.npy
#   inflating: 05gNigkqfNU_25_34.npy
#   inflating: 05gNigkqfNU_78_84.npy
#   inflating: 06CbMa0kDr8_3_13.npy
#   inflating: 08pVpBq706k_175_212.npy
#   inflating: 0GXq1An3yHI_22_35.npy
#   inflating: 0I4VKj4d0WI_24_40.npy
#   inflating: 0IDJG0q9j_k_1_24.npy
#   inflating: 0M-PyX2DbZc_25_31.npy
#   inflating: 0NPtAv3_uVI_46_54.npy
#   inflating: 0ONJfp95yoE_1_10.npy
#   inflating: 0RWJEOScToE_414_421.npy
#   inflating: 0SMOK2ql7Pg_5_12.npy
#   inflating: 0bSz70pYAP0_5_15.npy
#   inflating: 0hyZ__3YhZc_279_283.npy
#   inflating: 0hyZ__3YhZc_289_295.npy
#   inflating: 0hyZ__3YhZc_302_307.npy
#   inflating: 0hyZ__3YhZc_341_348.npy
#   inflating: 0hyZ__3YhZc_352_356.npy
#   inflating: 0hyZ__3YhZc_364_370.npy
#   inflating: 0hyZ__3YhZc_380_384.npy
#   inflating: 0hyZ__3YhZc_388_394.npy
#   inflating: 0hyZ__3YhZc_410_417.npy
#   inflating: 0hyZ__3YhZc_418_424.npy
#   inflating: 0hyZ__3YhZc_485_490.npy
#   inflating: 0hyZ__3YhZc_562_568.npy
#   inflating: 0hyZ__3YhZc_575_580.npy
#   inflating: 0hyZ__3YhZc_598_603.npy
#   inflating: 0hyZ__3YhZc_632_637.npy
#   inflating: 0k1Ak8aTMVI_4_12.npy
#   inflating: 0lh_UWF9ZP4_103_110.npy
#   inflating: 0lh_UWF9ZP4_138_145.npy
#   inflating: 0lh_UWF9ZP4_148_155.npy
#   inflating: 0lh_UWF9ZP4_157_160.npy
#   inflating: 0lh_UWF9ZP4_165_170.npy
#   inflating: 0lh_UWF9ZP4_174_178.npy
#   inflating: 0lh_UWF9ZP4_178_182.npy
#   inflating: 0lh_UWF9ZP4_183_190.npy
#   inflating: 0lh_UWF9ZP4_191_197.npy
#   inflating: 0lh_UWF9ZP4_199_207.npy
#   inflating: 0lh_UWF9ZP4_215_226.npy
#   inflating: 0lh_UWF9ZP4_21_26.npy
#   inflating: 0lh_UWF9ZP4_27_31.npy
#   inflating: 0lh_UWF9ZP4_38_46.npy
#   inflating: 0lh_UWF9ZP4_50_60.npy
#   inflating: 0lh_UWF9ZP4_62_69.npy
#   inflating: 0lh_UWF9ZP4_71_77.npy
#   inflating: 0lh_UWF9ZP4_79_82.npy
#   inflating: 0lh_UWF9ZP4_82_87.npy
#   inflating: 0lh_UWF9ZP4_94_103.npy
#   inflating: 0piwbTivpDg_10_40.npy
#   inflating: 0sUL0KCIc48_15_25.npy
#   inflating: 0vmoZEaN_-o_4_12.npy
#   inflating: 0vmoZEaN_-o_5_21.npy
#   inflating: 0wutCy2ZGOQ_4_10.npy
#   inflating: 0xx13BuvVmo_25_36.npy
#   inflating: 11xs9mFKObs_0_8.npy
#   inflating: 16iNk1hLJt4_37_40.npy
#   inflating: 1Dty_eGY9Ec_123_133.npy
#   inflating: 1N_Ic2pBM1o_2_23.npy
#   inflating: 1QVn0FffExM_14_24.npy
#   inflating: 1RchFBCT9JU_43_53.npy
#   inflating: 1Sp2__RCT0c_11_15.npy
#   inflating: 1TjqADyYyxI_36_45.npy
#   inflating: 1_6V30igzIk_5_15.npy
#   inflating: 1dA1RQgPN3c_72_82.npy
#   inflating: 1dYpcVv6n3Y_0_18.npy
#   inflating: 1dfR0A_BXjw_401_408.npy
#   inflating: 1dfR0A_BXjw_441_448.npy
#   inflating: 1dfR0A_BXjw_524_532.npy
#   inflating: 1dfR0A_BXjw_545_560.npy
#   inflating: 1dfR0A_BXjw_590_600.npy
#   inflating: 1hPxGmTGarM_9_19.npy
#   inflating: 1kYWws89W3Y_0_5.npy
#   inflating: 1mIyMRPV8kg_9_17.npy
#   inflating: 1pw5ZdRhiig_50_59.npy
#   inflating: 1qU-kF-km1Q_6_16.npy
#   inflating: 1qV4wfjTYIo_151_164.npy
#   inflating: 1qxMJLkHDLw_0_9.npy
#   inflating: 1rECrfrdNTo_200_207.npy
#   inflating: 1sffYOXq4Iw_23_49.npy
#   inflating: 21uB8g-jDZI_70_79.npy
#   inflating: 229NvV0SRHw_0_5.npy
#   inflating: 25NmudB2fqg_0_7.npy
#   inflating: 27hs9W89FuI_0_10.npy
#   inflating: 27mxaePkYB4_8_14.npy
#   inflating: 2F9jX7u5nOg_114_130.npy
#   inflating: 2F9jX7u5nOg_83_97.npy
#   inflating: 2FLsMPsywRc_45_63.npy
#   inflating: 2G9fkvBzzQE_10_20.npy
#   inflating: 2HpZvL-_fiY_40_44.npy
#   inflating: 2I20ZTFHheg_96_104.npy
#   inflating: 2KrdBUFeFtY_22_27.npy
#   inflating: 2L4oELbX8Ms_1_12.npy
#   inflating: 2LgrGHWSy6k_122_135.npy
#   inflating: 2MCpA01Sn_c_75_82.npy
#   inflating: 2Nn2CAeaI5k_72_77.npy
#   inflating: 2R_OAYQIkXM_14_22.npy
#   inflating: 2YhDTpzxd3c_102_105.npy
#   inflating: 2YhDTpzxd3c_115_120.npy
#   inflating: 2YhDTpzxd3c_149_154.npy
#   inflating: 2YhDTpzxd3c_166_170.npy
#   inflating: 2YhDTpzxd3c_174_180.npy
#   inflating: 2YhDTpzxd3c_223_232.npy
#   inflating: 2YhDTpzxd3c_22_27.npy
#   inflating: 2YhDTpzxd3c_240_245.npy
#   inflating: 2YhDTpzxd3c_45_49.npy
#   inflating: 2YhDTpzxd3c_98_101.npy
#   inflating: 2jXxtQRy47A_30_38.npy
#   inflating: 2jkExrrm_sQ_19_25.npy
#   inflating: 2mUMTFnQWaw_1_9.npy
#   inflating: 2xpIT0L4GqE_1_10.npy
#   inflating: 30GeJHYoerk_121_126.npy
#   inflating: 30GeJHYoerk_63_75.npy
#   inflating: 30GeJHYoerk_80_85.npy
#   inflating: 30PpKtVT8Z4_35_50.npy
#   inflating: 32_A0-er4Ws_16_20.npy
#   inflating: 39Ce7I6nXIw_96_104.npy
#   inflating: 3FnUTQMJVXI_31_36.npy
#   inflating: 3I9tSDU-OSk_17_22.npy
#   inflating: 3OPQqH3YlHA_50_54.npy
#   inflating: 3SKyc0aKx70_46_52.npy
#   inflating: 3_51FhosiVY_93_101.npy
#   inflating: 3chNlP5TeO8_0_10.npy
#   inflating: 3doK4FQM5-k_46_57.npy
#   inflating: 3eqFFRSXwGE_84_96.npy
#   inflating: 3ftaoFnhTyY_140_150.npy
#   inflating: 3lBHYoI5V8s_30_45.npy
#   inflating: 3mbBbFH9fAg_21_29.npy
#   inflating: 3n_Kqak2JdA_48_71.npy
#   inflating: 3opDcpPxllE_50_66.npy
#   inflating: 3qqEKTPxLNs_1_15.npy
#   inflating: 3ytUOoa1SBE_12_23.npy
#   inflating: 3zgEl-OLFKE_12_15.npy
#   inflating: 3zrVqwV29V8_69_76.npy
#   inflating: 4-1gpwkD7Hc_7_15.npy
#   inflating: 45AGQSbodbU_5_15.npy
#   inflating: 47D9-U8hn5I_11_16.npy
#   inflating: 4D1o4FC8YbA_207_216.npy
#   inflating: 4D1o4FC8YbA_29_39.npy
#   inflating: 4Hhdr1IPOGs_1_10.npy
#   inflating: 4Hhdr1IPOGs_90_98.npy
#   inflating: 4JVpbYmqfcI_5_19.npy
#   inflating: 4MjTb5A68VA_111_118.npy
#   inflating: 4PayIIIOeIs_230_238.npy
#   inflating: 4PcL6-mjRNk_11_18.npy
#   inflating: 4PcL6-mjRNk_47_55.npy
#   inflating: 4QYPZM01xFE_14_26.npy
#   inflating: 4QdX5Q3qQsQ_38_44.npy
#   inflating: 4QdX5Q3qQsQ_6_14.npy
#   inflating: 4R-tumAGrtU_12_22.npy
#   inflating: 4Tn5S48sCwg_110_118.npy
#   inflating: 4UOVKok7j1U_1_8.npy
#   inflating: 4VLrxtf7Z_8_0_7.npy
#   inflating: 4_WZN7uW0NY_140_145.npy
#   inflating: 4cgzdXlJksU_83_90.npy
#   inflating: 4eJJF11bIxM_1_9.npy
#   inflating: 4ge5_V-xhP0_138_142.npy
#   inflating: 4ge5_V-xhP0_35_42.npy
#   inflating: 4ikH9ZRcF2Q_89_105.npy
#   inflating: 4kQnrKvOTNg_15_24.npy
#   inflating: 4lXdVS697DQ_10_25.npy
#   inflating: 4s_0-zIWEog_1_15.npy
#   inflating: 4t5POXt2e68_5_11.npy
#   inflating: 4wT7zM8XgXQ_5_11.npy
#   inflating: 4xVGpDmA4lE_23_33.npy
#   inflating: 4yYapi-5QYQ_33_57.npy
#   inflating: 4yf2WP6K1gQ_28_32.npy
#   inflating: 4z3b4mnw5y4_56_60.npy
#   inflating: 4zPSShqsq-o_3_16.npy
#   inflating: 5-8z5U-o4O4_0_3.npy
#   inflating: 504gE1DA_4g_1_6.npy
#   inflating: 53dc4z7HLyg_16_23.npy
#   inflating: 53dc4z7HLyg_25_29.npy
#   inflating: 57C93mpt6Xo_358_368.npy
#   inflating: 5AEldiUP408_65_71.npy
#   inflating: 5CS4nLI2ZX8_50_59.npy
#   inflating: 5CU2JhYM8tY_14_45.npy
#   inflating: 5E66Gk3V1Bc_23_30.npy
#   inflating: 5EXVeP6R3yc_105_108.npy
#   inflating: 5HAf_INrFy0_3_25.npy
#   inflating: 5JLi7L1Kwp8_23_30.npy
#   inflating: 5JSbxHECb-I_97_110.npy
#   inflating: 5K7Ru5s6YIw_8_11.npy
#   inflating: 5L5MoemWC6g_10_13.npy
#   inflating: 5OuYhq6Zl0g_0_10.npy
#   inflating: 5OvgDatToBU_0_8.npy
#   inflating: 5P6UU6m3cqk_57_75.npy
#   inflating: 5PpPOGU_0aA_65_75.npy
#   inflating: 5QJf-l4lPJw_133_138.npy
#   inflating: 5U3xz9Ovmhk_214_222.npy
#   inflating: 5U3xz9Ovmhk_258_265.npy
#   inflating: 5U3xz9Ovmhk_99_105.npy
#   inflating: 5U3xz9Ovmhk_9_15.npy
#   inflating: 5W02895vT8c_312_322.npy
#   inflating: 5W02895vT8c_460_470.npy
#   inflating: 5XxshEdcfAM_85_100.npy
#   inflating: 5XxshEdcfAM_96_107.npy
#   inflating: 5YJaS2Eswg0_22_26.npy
#   inflating: 5dZ8PXABC30_14_20.npy
#   inflating: 5dv8MSWlxoQ_10_40.npy
#   inflating: 5fDBl1wT2Lk_34_39.npy
#   inflating: 5fq9iIxxA1s_12_27.npy
#   inflating: 5l6acVf12S4_7_13.npy
#   inflating: 5x_OGEdO6Z8_0_21.npy
#   inflating: 5zkCnHUnoYY_69_74.npy
#   inflating: 60x_yxy7Sfw_1_7.npy
#   inflating: 62I8I4sCPPQ_12_30.npy
#   inflating: 64Xn9edeWRA_0_11.npy
#   inflating: 6BrHPMdyVtU_1_10.npy
#   inflating: 6FmN22YcVVE_11_18.npy
#   inflating: 6GJ1DNOGDAM_223_233.npy
#   inflating: 6JnGBs88sL0_4_10.npy
#   inflating: 6KS8R3RxrV8_0_23.npy
#   inflating: 6Lzq1HN33lE_5_15.npy
#   inflating: 6Q3ltyPJJMQ_67_72.npy
#   inflating: 6QbhfbLUtQs_13_23.npy
#   inflating: 6RlYLTU5gvM_18_24.npy
#   inflating: 6ZZkO14S7GY_5_15.npy
#   inflating: 6ZhKOK08tgM_225_233.npy
#   inflating: 6ZhKOK08tgM_45_49.npy
#   inflating: 6eokrw6_bjU_1_9.npy
#   inflating: 6gQu8PWhFoQ_30_35.npy
#   inflating: 6gQu8PWhFoQ_37_41.npy
#   inflating: 6mYnZbIwcNo_10_16.npy
#   inflating: 6njscWrdnM0_8_18.npy
#   inflating: 6owu8Mow0_g_275_280.npy
#   inflating: 6owu8Mow0_g_302_307.npy
#   inflating: 6owu8Mow0_g_384_389.npy
#   inflating: 6owu8Mow0_g_527_534.npy
#   inflating: 6owu8Mow0_g_692_697.npy
#   inflating: 6owu8Mow0_g_850_855.npy
#   inflating: 6pcqRuFEMLs_46_52.npy
#   inflating: 6q1dX6thX3E_286_295.npy
#   inflating: 6r5DmFa5ZR8_51_58.npy
#   inflating: 6sKdTbRkahM_6_12.npy
#   inflating: 6sYmDT5et00_301_339.npy
#   inflating: 6t0BpjwYKco_105_110.npy
#   inflating: 6t0BpjwYKco_118_127.npy
#   inflating: 6t0BpjwYKco_142_151.npy
#   inflating: 6t0BpjwYKco_15_31.npy
#   inflating: 6t0BpjwYKco_179_183.npy
#   inflating: 6t0BpjwYKco_200_205.npy
#   inflating: 6t0BpjwYKco_217_229.npy
#   inflating: 6t0BpjwYKco_230_240.npy
#   inflating: 6t0BpjwYKco_240_247.npy
#   inflating: 6t0BpjwYKco_254_258.npy
#   inflating: 6t0BpjwYKco_261_284.npy
#   inflating: 6t0BpjwYKco_46_53.npy
#   inflating: 6t0BpjwYKco_53_59.npy
#   inflating: 6t0BpjwYKco_59_69.npy
#   inflating: 6t0BpjwYKco_71_76.npy
#   inflating: 6t0BpjwYKco_80_84.npy
#   inflating: 6vC6AT27RUc_29_46.npy
#   inflating: 6vSKIUGGLvY_81_87.npy
#   inflating: 71soiLO6I9U_15_24.npy
#   inflating: 73vUksucPz8_12_20.npy
#   inflating: 74tRCYS_534_49_57.npy
#   inflating: 778mkceE0UQ_40_46.npy
#   inflating: 77iDIp40m9E_119_123.npy
#   inflating: 77iDIp40m9E_126_131.npy
#   inflating: 77iDIp40m9E_159_181.npy
#   inflating: 77iDIp40m9E_3_9.npy
#   inflating: 7EOqi_6rnkg_36_44.npy
#   inflating: 7HcYJKMxpcg_20_28.npy
#   inflating: 7M-jsjLB20Y_11_30.npy
#   inflating: 7NNg0_n-bS8_21_30.npy
#   inflating: 7OGizkf_JEo_191_194.npy
#   inflating: 7ZE2OzguWHo_28_38.npy
#   inflating: 7_XASfcYdBk_3_13.npy
#   inflating: 7bcV-TL9mho_0_7.npy
#   inflating: 7d1d2WlEnKs_0_12.npy
#   inflating: 7s0AXJtLL0Y_57_61.npy
#   inflating: 7uF-2adCsI0_60_67.npy
#   inflating: 7uOiiA4Kxbo_23_35.npy
#   inflating: 7xNG7qGY9rw_14_29.npy
#   inflating: 80D0ylOqPJ8_0_5.npy
#   inflating: 81fABEiwcIM_31_45.npy
#   inflating: 88DOMJ11q2M_34_43.npy
#   inflating: 88DOMJ11q2M_84_87.npy
#   inflating: 88p7U5CnoYU_1_10.npy
#   inflating: 8BL9qmFRbd4_6_13.npy
#   inflating: 8CzlhZtunNc_5_11.npy
#   inflating: 8D_oQnBPfNo_43_50.npy
#   inflating: 8HB7ywgJuTg_131_142.npy
#   inflating: 8MVo7fje_oE_108_113.npy
#   inflating: 8MVo7fje_oE_113_118.npy
#   inflating: 8MVo7fje_oE_125_130.npy
#   inflating: 8MVo7fje_oE_130_136.npy
#   inflating: 8MVo7fje_oE_139_144.npy
#   inflating: 8MVo7fje_oE_153_158.npy
#   inflating: 8MVo7fje_oE_166_171.npy
#   inflating: 8MVo7fje_oE_180_185.npy
#   inflating: 8MVo7fje_oE_85_90.npy
#   inflating: 8NFoN0K3bPg_20_28.npy
#   inflating: 8PQiaurIiDM_143_151.npy
#   inflating: 8PQiaurIiDM_173_180.npy
#   inflating: 8PQiaurIiDM_247_255.npy
#   inflating: 8PQiaurIiDM_94_99.npy
#   inflating: 8VUbN3hkdBo_36_50.npy
#   inflating: 8e0yXMa708Y_24_33.npy
#   inflating: 8jP8CC2rKj4_80_88.npy
#   inflating: 8mSUD7JGNO0_174_181.npy
#   inflating: 8mSUD7JGNO0_198_204.npy
#   inflating: 8sARjdhSvpo_167_176.npy
#   inflating: 8yS2wqwActs_2_14.npy
#   inflating: 8yoUaH6wGLs_22_30.npy
#   inflating: 8yuPGwxwdPs_1_10.npy
#   inflating: 8z-XGiU1KN4_9_17.npy
#   inflating: 93n_oYVCLpk_9_12.npy
#   inflating: 953PkxFNiko_82_85.npy
#   inflating: 97JhYpoWxzY_0_4.npy
#   inflating: 98Alrg4pFXs_148_153.npy
#   inflating: 98shpdib9sg_55_62.npy
#   inflating: 992zi9V3oiQ_15_17.npy
#   inflating: 9BScZRpF7SI_31_36.npy
#   inflating: 9Bxknsvy3jQ_53_58.npy
#   inflating: 9HDUADeA2xg_3_31.npy
#   inflating: 9HTUcMjWB3g_122_128.npy
#   inflating: 9HTUcMjWB3g_134_138.npy
#   inflating: 9HTUcMjWB3g_143_151.npy
#   inflating: 9IrWyZ0KZuk_160_166.npy
#   inflating: 9LHg5RUGukI_58_63.npy
#   inflating: 9LHg5RUGukI_63_68.npy
#   inflating: 9LOJmQQktHA_10_18.npy
#   inflating: 9LSuyLyuUiM_3_6.npy
#   inflating: 9OvXb1fot74_21_29.npy
#   inflating: 9OxQ-2gR1DU_18_38.npy
#   inflating: 9Q0JfdP36kI_167_170.npy
#   inflating: 9Q0JfdP36kI_19_27.npy
#   inflating: 9Q0JfdP36kI_23_28.npy
#   inflating: 9Q0JfdP36kI_56_64.npy
#   inflating: 9QI8cgBSGo8_28_41.npy
#   inflating: 9VG7Elw9TDA_85_91.npy
#   inflating: 9W6aQNcU3PA_92_103.npy
#   inflating: 9WpJxn-2h1o_122_150.npy
#   inflating: 9Wr48VFhZH8_45_50.npy
#   inflating: 9d57lHEsLU8_1_14.npy
#   inflating: 9fkS7wqrzAY_13_25.npy
#   inflating: 9gbUM9oHBNI_557_563.npy
#   inflating: 9uDPqigcnzw_36_46.npy
#   inflating: 9wxB1UQi0MM_18_38.npy
#   inflating: 9xVqwy_4pmQ_36_49.npy
#   inflating: 9zXqkHvs0po_59_65.npy
#   inflating: A6XrTsLsUbA_4_15.npy
#   inflating: ACK7SekJWts_140_150.npy
#   inflating: ACOmKiJDkA4_121_128.npy
#   inflating: ACOmKiJDkA4_130_144.npy
#   inflating: ACOmKiJDkA4_146_153.npy
#   inflating: ACOmKiJDkA4_161_170.npy
#   inflating: ACOmKiJDkA4_175_182.npy
#   inflating: ACOmKiJDkA4_20_26.npy
#   inflating: ACOmKiJDkA4_23_30.npy
#   inflating: ACOmKiJDkA4_47_54.npy
#   inflating: ACOmKiJDkA4_49_54.npy
#   inflating: ACOmKiJDkA4_57_65.npy
#   inflating: ACOmKiJDkA4_67_74.npy
#   inflating: ACOmKiJDkA4_75_81.npy
#   inflating: AE9UaQwum8c_0_10.npy
#   inflating: AEKPjVHSVZc_0_12.npy
#   inflating: AGRFy5hDQiY_31_38.npy
#   inflating: AJJ-iQkbRNE_97_109.npy
#   inflating: AKVBK-0veE8_5_12.npy
#   inflating: AQhiE_NL6yY_91_101.npy
#   inflating: AX38yo7Wuws_81_91.npy
#   inflating: AXL1oMdCFUM_45_59.npy
#   inflating: A_nCfAbXjoM_8_56.npy
#   inflating: Aa7yf9XtcJM_45_50.npy
#   inflating: AdcgmBtE99c_108_114.npy
#   inflating: Afmc6FeN-hM_20_24.npy
#   inflating: AjZ-R3LFMzo_18_23.npy
#   inflating: AjZ-R3LFMzo_24_38.npy
#   inflating: AjZ-R3LFMzo_5_10.npy
#   inflating: AoNnzlGhI04_112_128.npy
#   inflating: ApYvvQK7bBc_6_32.npy
#   inflating: Ar70p1_LcfM_2_20.npy
#   inflating: ArEWo8pERFc_17_21.npy
#   inflating: Ayh26v6Nies_17_22.npy
#   inflating: AysIdzGF-7M_6_14.npy
#   inflating: AzMrltkXGJk_0_10.npy
#   inflating: B-Lsf7ZKf5c_10_25.npy
#   inflating: B4foOe9kUgY_0_8.npy
#   inflating: B7mP4zoDMwM_0_17.npy
#   inflating: BAf3LXFUaGs_28_38.npy
#   inflating: BApIQn69EVE_10_16.npy
#   inflating: BE_uxYK9uz0_150_168.npy
#   inflating: BE_uxYK9uz0_49_56.npy
#   inflating: BGG0uYWZBdw_6_12.npy
#   inflating: BIqVvRh_cEY_143_149.npy
#   inflating: BLXzfdNmydQ_151_156.npy
#   inflating: BOLKaQeB6j0_101_111.npy
#   inflating: BOv-2HzNPaA_7_12.npy
#   inflating: BR4yQFZK9YM_101_110.npy
#   inflating: BVilbVCo9sU_1_11.npy
#   inflating: BVjvRpmHg0w_121_130.npy
#   inflating: BVjvRpmHg0w_157_165.npy
#   inflating: BVjvRpmHg0w_231_250.npy
#   inflating: BVjvRpmHg0w_47_51.npy
#   inflating: BVy9SQI5R68_0_7.npy
#   inflating: BefkDBj5gSw_104_109.npy
#   inflating: BefkDBj5gSw_233_240.npy
#   inflating: BgoOihBb78w_38_40.npy
#   inflating: BnJUWwSx1kE_11_22.npy
#   inflating: BtQEY2SL4g4_11_16.npy
#   inflating: BtQEY2SL4g4_126_132.npy
#   inflating: BtQtRGI0F2Q_15_20.npy
#   inflating: BvHnDAsMtUA_0_13.npy
#   inflating: ByGspTdA1ug_16_24.npy
#   inflating: C12BRGGcd5E_101_117.npy
#   inflating: C1MNCR1o9lU_0_7.npy
#   inflating: C2rDp6FnbP0_10_17.npy
#   inflating: C9LHk0AJI7U_196_205.npy
#   inflating: C9vRgZDxTv4_26_33.npy
#   inflating: CBD9h0jUq3w_1_7.npy
#   inflating: CGllPWAwmUo_1_15.npy
#   inflating: CHFXTeQWXjo_206_212.npy
#   inflating: CHVhwcOg6y8_1_12.npy
#   inflating: CL49s8bO6Fg_1_11.npy
#   inflating: CTIKmoEigCI_3_30.npy
#   inflating: C_1cnNdMwxY_0_8.npy
#   inflating: C_DDjCRxTxQ_1_4.npy
#   inflating: CcvJs77L-e8_15_22.npy
#   inflating: Ce7equ9zCxk_4_19.npy
#   inflating: CgWYN5e9K10_30_62.npy
#   inflating: Cjf21Y19aUQ_82_86.npy
#   inflating: CjvMNwpAFWM_56_66.npy
#   inflating: CquJjlNuotg_147_155.npy
#   inflating: CulG2SMC7DU_14_25.npy
#   inflating: CwPfvoqmV1Q_58_61.npy
#   inflating: Cx1We6GX4IM_0_8.npy
#   inflating: Cxxx6wJ1jNo_0_10.npy
#   inflating: D1X6qXkLjYE_41_49.npy
#   inflating: D1tTBncIsm8_198_205.npy
#   inflating: D1tTBncIsm8_248_254.npy
#   inflating: D1tTBncIsm8_681_688.npy
#   inflating: D1tTBncIsm8_725_740.npy
#   inflating: D1tTBncIsm8_841_848.npy
#   inflating: D2FbgK_kkE8_121_151.npy
#   inflating: D9I1Z6O_mbw_112_119.npy
#   inflating: D9I1Z6O_mbw_141_146.npy
#   inflating: DAmOfcvfKZ0_22_32.npy
#   inflating: DB-3-TVjrxU_58_75.npy
#   inflating: DBvSfds3FH4_76_80.npy
#   inflating: DBvSfds3FH4_84_88.npy
#   inflating: DDtX5a-OgLQ_1_15.npy
#   inflating: DGQL5lx-mwE_2_12.npy
#   inflating: DIToA1dDwGQ_32_42.npy
#   inflating: DIebwNHGjm8_133_148.npy
#   inflating: DIebwNHGjm8_27_38.npy
#   inflating: DJWmm_Q9WvY_1_25.npy
#   inflating: DKZg4kIEa0A_31_36.npy
#   inflating: DKgHYLDebx0_0_8.npy
#   inflating: DLcuZ-HnHZc_0_10.npy
#   inflating: DN7jwyL1Xgg_1_19.npy
#   inflating: DcDYRpa34W8_11_25.npy
#   inflating: De815YpTBic_41_48.npy
#   inflating: Dgf0VHMEtNs_57_66.npy
#   inflating: DhwrBs96Kgk_120_124.npy
#   inflating: DlOhXqKcLXk_7_14.npy
#   inflating: DuMkW35BwK8_43_47.npy
#   inflating: DvYN53KBDr0_51_62.npy
#   inflating: E2r6nnkwl0c_6_18.npy
#   inflating: E4k0Aylzdyo_97_104.npy
#   inflating: E61HNXjgyqA_22_32.npy
#   inflating: E6sqA9QtV5I_195_201.npy
#   inflating: EA-J-Y6QjUo_40_61.npy
#   inflating: EBWPZIjtnTM_1_6.npy
#   inflating: EKL6elkbFy0_16_30.npy
#   inflating: EPXsiQw9vvo_1_12.npy
#   inflating: EPgQ9QwbsLE_16_23.npy
#   inflating: ETUJipdnfOM_0_5.npy
#   inflating: EVqc7e8JCco_5_15.npy
#   inflating: EXyp0Q7L1zE_30_38.npy
#   inflating: Ea0thGZKPXA_25_35.npy
#   inflating: Eamd2wMKixs_48_72.npy
#   inflating: EdrZtaBUXIo_25_29.npy
#   inflating: EiylMb_mWk4_2_20.npy
#   inflating: EjAoBKagWQA_132_145.npy
#   inflating: Els1Cclg_sk_4_15.npy
#   inflating: EpMuCrbxE8A_107_115.npy
#   inflating: EqOGzNkekMk_5_15.npy
#   inflating: EwTZ2xpQwpA_14_21.npy
#   inflating: F1BwUJ4--Qw_21_38.npy
#   inflating: F2Ny7rq9RKs_139_148.npy
#   inflating: F3pmw2ga244_59_65.npy
#   inflating: F44bLc6t7-I_1_8.npy
#   inflating: FA3OfhJK0mI_195_203.npy
#   inflating: FAD8CbQuvco_35_45.npy
#   inflating: FCjpuJaUec0_19_26.npy
#   inflating: FGjtmhI-Rmk_30_37.npy
#   inflating: FH8vgAp4VDU_10_14.npy
#   inflating: FHwC2THZJfA_0_10.npy
#   inflating: FOOM-wA2rOY_77_86.npy
#   inflating: FTh5zPk34bQ_16_30.npy
#   inflating: FWzsXeXCwuc_106_110.npy
#   inflating: FWzsXeXCwuc_111_116.npy
#   inflating: FXWdmIHXS_U_3_10.npy
#   inflating: FavUpD_IjVY_22_26.npy
#   inflating: Fe4tO5vW9_E_64_70.npy
#   inflating: FeTaKOPVaJg_15_25.npy
#   inflating: FeTaKOPVaJg_60_70.npy
#   inflating: Ffv7fhL1EDY_177_184.npy
#   inflating: FoL7aWvpvNs_199_204.npy
#   inflating: FvfjDQj5sOY_1_10.npy
#   inflating: FwCmcZpkk-k_22_32.npy
#   inflating: FxIuFwMhOu8_18_26.npy
#   inflating: G-M78KIy19E_315_330.npy
#   inflating: G6w6kO8UPyg_31_41.npy
#   inflating: GEXqMH8I3_w_14_18.npy
#   inflating: GEXqMH8I3_w_63_68.npy
#   inflating: GMuijLIJH-U_1_10.npy
#   inflating: GPT4vUwlrXY_1_10.npy
#   inflating: GPyFZMJ5Dow_56_70.npy
#   inflating: GWQTAe64m-0_160_166.npy
#   inflating: GWQTAe64m-0_91_94.npy
#   inflating: GY5Dl00LrEI_2_13.npy
#   inflating: G_hxdUG6QXE_23_28.npy
#   inflating: GcfWD62sbcs_13_33.npy
#   inflating: Gh4Beb8StFM_29_50.npy
#   inflating: GlW6n43pUQA_0_12.npy
#   inflating: Gm1WnWVXYzQ_0_9.npy
#   inflating: Gn4Iv5ARIXc_37_40.npy
#   inflating: Gn4Iv5ARIXc_83_93.npy
#   inflating: GnwKcpfr_ng_10_20.npy
#   inflating: GnwKcpfr_ng_47_57.npy
#   inflating: Goj131_GxYs_2_7.npy
#   inflating: GopEjCCu2jo_2_9.npy
#   inflating: GtrTNldo0LI_33_46.npy
#   inflating: Gw0FU733zzg_58_66.npy
#   inflating: GyIs9B3A1Z0_0_7.npy
#   inflating: GzlnqrzdYHU_32_40.npy
#   inflating: H1Bok7Dg7g8_21_26.npy
#   inflating: H7vezmDeZaw_2_7.npy
#   inflating: H9Oplnr8WcE_24_34.npy
#   inflating: HAjwXjwN9-A_16_24.npy
#   inflating: HBCJYhUjVf0_0_9.npy
#   inflating: HDcIB1e9s5A_28_34.npy
#   inflating: HJHPB_Y8GZE_22_28.npy
#   inflating: HJHPB_Y8GZE_259_263.npy
#   inflating: HM-ZDoRWiH4_0_5.npy
#   inflating: HN-ccxID8IM_3_10.npy
#   inflating: HO_ovIrLWfQ_1_11.npy
#   inflating: HPFLN5azwtA_56_63.npy
#   inflating: HV12kTtdTT4_5_14.npy
#   inflating: HVR7KpItLfA_62_70.npy
#   inflating: HYbEf-JKZnA_13_26.npy
#   inflating: HZ-BuDDmvVk_0_10.npy
#   inflating: HZqscSWtHmo_24_34.npy
#   inflating: Hd-NeIhbYGc_28_31.npy
#   inflating: Hd-NeIhbYGc_43_48.npy
#   inflating: He7Ge7Sogrk_47_70.npy
#   inflating: HkpUWzNNVt4_20_30.npy
#   inflating: HkuOqWzXYVg_0_12.npy
#   inflating: HmVPxs4ygMc_44_53.npy
#   inflating: HqbVbPvlDoM_0_11.npy
#   inflating: Hu9Sq1RvuoA_19_62.npy
#   inflating: HxRK-WqZ5Gk_30_50.npy
#   inflating: HypgcCT1r68_38_46.npy
#   inflating: HzYtvOYOEoU_21_32.npy
#   inflating: I9gLTZY1ouc_142_147.npy
#   inflating: IAvBB2lv8iw_142_148.npy
#   inflating: IBgsLmDcL78_80_84.npy
#   inflating: ID2xXlUENG0_19_24.npy
#   inflating: IEQyCcageGg_99_126.npy
#   inflating: IHIa75B9AhI_2_26.npy
#   inflating: INDhUwDMg-4_220_227.npy
#   inflating: ITNh8tWZPOA_5_25.npy
#   inflating: IWhrWLOAin0_1_4.npy
#   inflating: IY1Fn796MoY_7_10.npy
#   inflating: I_-Nb_0RxpM_1_15.npy
#   inflating: IhwPQL9dFYc_124_129.npy
#   inflating: IhwPQL9dFYc_130_136.npy
#   inflating: IhwPQL9dFYc_137_143.npy
#   inflating: IhwPQL9dFYc_143_147.npy
#   inflating: IhwPQL9dFYc_153_170.npy
#   inflating: IhwPQL9dFYc_171_175.npy
#   inflating: IhwPQL9dFYc_24_30.npy
#   inflating: IhwPQL9dFYc_50_59.npy
#   inflating: IhwPQL9dFYc_61_75.npy
#   inflating: IhwPQL9dFYc_78_88.npy
#   inflating: IhzXQ-gc9IQ_125_129.npy
#   inflating: IiIiY6o-C9k_49_55.npy
#   inflating: IiIiY6o-C9k_59_64.npy
#   inflating: IiTzJQE67FA_36_46.npy
#   inflating: IiTzJQE67FA_74_86.npy
#   inflating: IpHJffM3G1c_412_418.npy
#   inflating: IpHJffM3G1c_439_446.npy
#   inflating: IpHJffM3G1c_464_470.npy
#   inflating: ItFqogTmAvQ_240_246.npy
#   inflating: ItFqogTmAvQ_281_286.npy
#   inflating: ItFqogTmAvQ_361_365.npy
#   inflating: ItFqogTmAvQ_389_395.npy
#   inflating: ItFqogTmAvQ_48_52.npy
#   inflating: Ixw6wmoC_xg_116_126.npy
#   inflating: Ixw6wmoC_xg_60_70.npy
#   inflating: IytNBm8WA1c_63_67.npy
#   inflating: J---aiyznGQ_0_6.npy
#   inflating: J3_hkgu6MGc_43_52.npy
#   inflating: J4otiwOjQy8_98_112.npy
#   inflating: J7zb8YXrmIA_93_99.npy
#   inflating: J8cP93yG1Ao_14_24.npy
#   inflating: JAFGw0WRHHU_108_116.npy
#   inflating: JIKaIriiK8w_0_15.npy
#   inflating: JIoiUNOXGaI_34_41.npy
#   inflating: JIoiUNOXGaI_8_13.npy
#   inflating: JIoiUNOXGaI_98_104.npy
#   inflating: JK1R9k1WDpc_6_15.npy
#   inflating: JM4913Fe-ic_4_15.npy
#   inflating: JMUAylpXzG0_45_62.npy
#   inflating: JXSkYkiKO0I_112_116.npy
#   inflating: JXSkYkiKO0I_42_46.npy
#   inflating: JYNzY9jmsQQ_2_10.npy
#   inflating: J_evFB7RIKA_104_120.npy
#   inflating: Jag7oTemldY_12_25.npy
#   inflating: Je3V7U5Ctj4_488_495.npy
#   inflating: Je3V7U5Ctj4_504_511.npy
#   inflating: Je3V7U5Ctj4_558_563.npy
#   inflating: Je3V7U5Ctj4_569_576.npy
#   inflating: Je3V7U5Ctj4_582_587.npy
#   inflating: Je3V7U5Ctj4_634_639.npy
#   inflating: Je3V7U5Ctj4_760_765.npy
#   inflating: Je3V7U5Ctj4_768_773.npy
#   inflating: Je3V7U5Ctj4_956_961.npy
#   inflating: Je3V7U5Ctj4_997_1004.npy
#   inflating: Jfu-WkuCgD0_140_150.npy
#   inflating: JhCvLmf9yr0_46_50.npy
#   inflating: Jj4uYHr65H8_28_35.npy
#   inflating: JktNQQnLblQ_4_9.npy
#   inflating: JledeVyklPw_1_6.npy
#   inflating: JnNe61UZsdM_42_51.npy
#   inflating: JnNe61UZsdM_78_88.npy
#   inflating: JntMAcTlOF0_50_70.npy
#   inflating: JpjAgSvr42k_0_12.npy
#   inflating: JsD6uEZsIsU_1_47.npy
#   inflating: JsD6uEZsIsU_45_58.npy
#   inflating: JsmHZlUgf1w_0_21.npy
#   inflating: Jxw16bqzVqE_18_28.npy
#   inflating: K-KVz3eqbnA_1_10.npy
#   inflating: K-czl524zxk_6_15.npy
#   inflating: K1ZM0LSLVw8_481_487.npy
#   inflating: K1ZM0LSLVw8_488_494.npy
#   inflating: K2LxyytY3Dw_104_112.npy
#   inflating: K6xy6C-Hsa0_2_28.npy
#   inflating: KFt5Zz5Mwlo_12_30.npy
#   inflating: KIEWo_xJ5nU_0_7.npy
#   inflating: KPPCwmU5OHQ_227_238.npy
#   inflating: KPPCwmU5OHQ_258_266.npy
#   inflating: KPPCwmU5OHQ_424_430.npy
#   inflating: KPPCwmU5OHQ_467_472.npy
#   inflating: KPPCwmU5OHQ_480_486.npy
#   inflating: KPPCwmU5OHQ_56_62.npy
#   inflating: KUc1cWKXjDc_20_30.npy
#   inflating: KeSQ5Rv7eH8_73_79.npy
#   inflating: Kf8oZGHDTt4_4_13.npy
#   inflating: Kms3EXosNS0_8_17.npy
#   inflating: KpmVL4ANieA_0_9.npy
#   inflating: KqKUXRHHkCc_101_105.npy
#   inflating: Kqb-mmkEWqU_1_5.npy
#   inflating: KrBeBabazDU_15_20.npy
#   inflating: Kxa0mnDj0bs_113_124.npy
#   inflating: Kxa0mnDj0bs_15_20.npy
#   inflating: L6dEUQ6WiHY_136_142.npy
#   inflating: L6dEUQ6WiHY_171_186.npy
#   inflating: L8h2DazQZJY_0_10.npy
#   inflating: L9wD3kw-8FE_65_73.npy
#   inflating: LEz0puaKNTk_38_48.npy
#   inflating: LF51fban_x4_300_325.npy
#   inflating: LLkehH86ABY_30_36.npy
#   inflating: LQ-jv8g1YVI_1_6.npy
#   inflating: LSuVRWPoHr0_0_37.npy
#   inflating: LYSPQqUvNO0_43_57.npy
#   inflating: LacBy2NT3YQ_12_17.npy
#   inflating: Li3umATsU0E_1_5.npy
#   inflating: LjimLwAhAOQ_5_15.npy
#   inflating: LqPIBHAmt4E_22_30.npy
#   inflating: Lr8ds5iY5uk_8_15.npy
#   inflating: Lt1JijkvSKk_0_10.npy
#   inflating: LuQ0KiMMhoI_49_64.npy
#   inflating: Lw0eGsYxElA_11_14.npy
#   inflating: LwicaralvS0_90_104.npy
#   inflating: LwvyrDxM2G0_0_11.npy
#   inflating: Ly5D0z9gKtc_15_20.npy
#   inflating: LyYJiKxHZz0_0_10.npy
#   inflating: Lyp7MiaCXNE_114_120.npy
#   inflating: M4It3DrhbE0_13_22.npy
#   inflating: MF88IYF2MHY_25_59.npy
#   inflating: MHIVmf42Ao4_31_36.npy
#   inflating: MHWxjWwAbwM_10_25.npy
#   inflating: MICawzo1MqI_3_13.npy
#   inflating: MJNStEgDKXU_3_10.npy
#   inflating: MJoxGpEswOI_9_16.npy
#   inflating: MMnnqzOoMF0_68_72.npy
#   inflating: MPuKVz3sjBA_1_12.npy
#   inflating: MSrJTeKNzdI_32_36.npy
#   inflating: MTjrZthHwJQ_2_11.npy
#   inflating: MTkGPfMRXtc_5_21.npy
#   inflating: MW21lp833Vo_143_149.npy
#   inflating: MW21lp833Vo_8_16.npy
#   inflating: MWvCcwTw7Ac_154_181.npy
#   inflating: MWvCcwTw7Ac_78_86.npy
#   inflating: MWzeInQaUk4_12_20.npy
#   inflating: MY-rGamtAJc_6_22.npy
#   inflating: M_TP6UTrh30_343_358.npy
#   inflating: MdOAr_4FJvc_5_15.npy
#   inflating: MoqC84sXu88_47_59.npy
#   inflating: MqS82kBtUHQ_0_12.npy
#   inflating: MrMG15y3rWU_5_13.npy
#   inflating: MrQd1zUVRUM_103_110.npy
#   inflating: Ms3QdGIzltU_10_20.npy
#   inflating: Ms3QdGIzltU_1_16.npy
#   inflating: Mutb8BHFvzk_15_20.npy
#   inflating: MwOEK-KXSPc_1_10.npy
#   inflating: N2Cm0SLr0ZE_18_29.npy
#   inflating: N3A7944_UJw_63_70.npy
#   inflating: N5wsl86P37Q_1_15.npy
#   inflating: N6SglZopfmk_97_111.npy
#   inflating: NFxWwI0J3As_78_84.npy
#   inflating: NKtfKR4GNjU_0_20.npy
#   inflating: NMlKMfiHSho_1_15.npy
#   inflating: NNYLo1OeZ-Q_48_54.npy
#   inflating: NUYu9c9XsgY_7_21.npy
#   inflating: NV6pq1W-I4g_7_16.npy
#   inflating: NVGGgncVq-4_111_117.npy
#   inflating: NVGGgncVq-4_12_20.npy
#   inflating: NZWiKMZS_k8_39_48.npy
#   inflating: NaX51emUDn4_0_20.npy
#   inflating: NbOlG7THecM_25_34.npy
#   inflating: Nd45qJn61Dw_0_10.npy
#   inflating: Ne87egvJnWo_0_3.npy
#   inflating: NjCqtzZ3OtU_303_307.npy
#   inflating: NjCqtzZ3OtU_62_67.npy
#   inflating: NjblUomxFQo_100_108.npy
#   inflating: NoCgvH4xZHo_240_251.npy
#   inflating: NoCgvH4xZHo_56_63.npy
#   inflating: NoCgvH4xZHo_68_74.npy
#   inflating: O06WXS_XZN0_0_6.npy
#   inflating: O2qiPS2NCeY_2_18.npy
#   inflating: O9cOSO9L8Zs_1_16.npy
#   inflating: O9yLRzpPp44_167_190.npy
#   inflating: O9yLRzpPp44_36_55.npy
#   inflating: OBLIjdMIIt8_54_61.npy
#   inflating: OCcy9TDRGKo_118_127.npy
#   inflating: OCcy9TDRGKo_41_51.npy
#   inflating: OE6H_M52Sng_89_97.npy
#   inflating: OIg10Bl7urs_0_10.npy
#   inflating: OIjsSu_I4So_6_10.npy
#   inflating: OKBLPpAPp9c_2_17.npy
#   inflating: OO-5-eVEKPA_25_31.npy
#   inflating: OUII8_aOfNM_26_55.npy
#   inflating: OUII8_aOfNM_60_69.npy
#   inflating: OVEe1DMsOq0_43_52.npy
#   inflating: O_NWtDShLeg_21_25.npy
#   inflating: O_Pst-uryQI_1_14.npy
#   inflating: OaBmAg6gz30_4_18.npy
#   inflating: ObBss94n3gI_35_46.npy
#   inflating: OfgSCMxttCc_86_92.npy
#   inflating: Okg8QYhdtvU_48_53.npy
#   inflating: Okg8QYhdtvU_73_92.npy
#   inflating: OpR1Er5o6IY_209_217.npy
#   inflating: Oq3FV_zdyy0_843_855.npy
#   inflating: OvRmRN1-O0Q_21_25.npy
#   inflating: Ow_o78zjo14_42_57.npy
#   inflating: OxL9z2BzBnk_0_19.npy
#   inflating: P2WM91LENgk_40_50.npy
#   inflating: P4IjNV3lZkQ_136_144.npy
#   inflating: P6eo3LULuuc_1_11.npy
#   inflating: PAN5IVvMlVc_17_23.npy
#   inflating: PAm82v0AMFc_5_10.npy
#   inflating: PBHZtoygOYg_450_465.npy
#   inflating: PCXHuseKwDc_17_20.npy
#   inflating: PCXHuseKwDc_68_76.npy
#   inflating: PD6eQY7yCfw_32_37.npy
#   inflating: PECk9A-07Pw_1_9.npy
#   inflating: PHDmVhShE80_20_29.npy
#   inflating: PHDmVhShE80_36_46.npy
#   inflating: PHDmVhShE80_78_82.npy
#   inflating: PHDmVhShE80_82_86.npy
#   inflating: PJnJMp2ZpbA_3_15.npy
#   inflating: PNMsPz1701c_3_20.npy
#   inflating: POv7JaE3vJ8_40_50.npy
#   inflating: PQbkdRbir0M_45_53.npy
#   inflating: PTxHJMM6hHE_0_15.npy
#   inflating: PeUHy0A1GF0_105_112.npy
#   inflating: PeUHy0A1GF0_114_121.npy
#   inflating: PeUHy0A1GF0_122_127.npy
#   inflating: PeUHy0A1GF0_28_32.npy
#   inflating: PeUHy0A1GF0_51_55.npy
#   inflating: PeUHy0A1GF0_62_66.npy
#   inflating: PeUHy0A1GF0_68_73.npy
#   inflating: PeUHy0A1GF0_74_77.npy
#   inflating: PeUHy0A1GF0_78_85.npy
#   inflating: PeUHy0A1GF0_99_103.npy
#   inflating: Pgm-mOQu2MM_48_62.npy
#   inflating: PiyoeFC31kE_9_27.npy
#   inflating: PmrTDZy3f2M_35_39.npy
#   inflating: PqSZ89FqpiY_65_75.npy
#   inflating: PqvKNqkGI9o_47_52.npy
#   inflating: Pr5LQq42l4M_12_17.npy
#   inflating: PslVHtXc7Tg_8_14.npy
#   inflating: PuQVs2Ch1LY_5_15.npy
#   inflating: PugziVUikEg_117_140.npy
#   inflating: Puh1n8DTKw8_2_9.npy
#   inflating: Puv_4NtflqE_26_34.npy
#   inflating: Q-soOsOLIGQ_0_22.npy
#   inflating: Q6HuQEIJqcA_9_16.npy
#   inflating: Q7H9mI9dtMY_20_34.npy
#   inflating: QA_JTtM1hKA_5_15.npy
#   inflating: QGJy1K91gP4_90_100.npy
#   inflating: QGgJlHi3tjw_1_15.npy
#   inflating: QHkvBU8diwU_1_18.npy
#   inflating: QMJY29QMewQ_42_52.npy
#   inflating: QOmrchUPnBs_10_20.npy
#   inflating: QT8iCDc7NGU_18_23.npy
#   inflating: QTAqjSbMkXU_65_75.npy
#   inflating: QVSt5USMkMg_43_50.npy
#   inflating: QhRqJp-CgEs_7_14.npy
#   inflating: QjI3Y8ZKSqs_30_38.npy
#   inflating: Qjbcibrv3L0_26_32.npy
#   inflating: QklHhN8pQBE_0_10.npy
#   inflating: Qp-k0H93iJE_35_39.npy
#   inflating: QqYWLR47eLI_10_18.npy
#   inflating: QsC8__3lwO0_50_60.npy
#   inflating: QsvBYKaCXEc_5_15.npy
#   inflating: Qtu-PXuvCx4_12_17.npy
#   inflating: Qwn0Ni9G5ow_64_69.npy
#   inflating: QzcTlEpAigQ_0_14.npy
#   inflating: QzulzuWr0Zw_20_45.npy
#   inflating: R0e8ojL0vcc_8_14.npy
#   inflating: R1UrFBF_0iU_35_41.npy
#   inflating: R24RktgUi-s_24_28.npy
#   inflating: R24RktgUi-s_5_15.npy
#   inflating: R2DvpPTfl-E_20_25.npy
#   inflating: R3a9r8qFlhQ_0_12.npy
#   inflating: R8FDJgVW3Vc_0_4.npy
#   inflating: RJNBxdDQOw4_13_26.npy
#   inflating: RMznbCn5sQs_0_10.npy
#   inflating: RQYLGNbal2c_5_10.npy
#   inflating: RSx5G0_xH48_12_17.npy
#   inflating: RWWvWFeE6_Q_2_26.npy
#   inflating: RX6NSOuCCAE_13_27.npy
#   inflating: RZL9irxnhZ0_34_40.npy
#   inflating: Rf0TUCA3XNs_3_16.npy
#   inflating: RieF9wrFd8s_1_8.npy
#   inflating: RiglOfJon8I_3_18.npy
#   inflating: RjpbFlOHFps_8_25.npy
#   inflating: Rm-RnxN4oHA_215_225.npy
#   inflating: Rq_VfjGH7kg_104_110.npy
#   inflating: RvJH_POzxmc_10_25.npy
#   inflating: S-Civm_fbK8_20_26.npy
#   inflating: SFFfhAUEoj0_10_16.npy
#   inflating: SJZFNwfcSOw_3_18.npy
#   inflating: SKhmFSV-XB0_12_18.npy
#   inflating: SRzoLVNgHoI_56_66.npy
#   inflating: SULWQEAErKw_13_26.npy
#   inflating: SZP3Jpbbwj0_52_59.npy
#   inflating: SaOqf2d-y30_22_27.npy
#   inflating: SaYwh6chmiw_15_40.npy
#   inflating: ScdUht-pM6s_53_63.npy
#   inflating: Sg5rTYrkpnU_35_48.npy
#   inflating: Sj6GSmDpNDw_0_12.npy
#   inflating: Sq7Vt6KC9Yg_17_35.npy
#   inflating: SrDE9-cDz48_4_12.npy
#   inflating: SzEbtbNSg04_111_117.npy
#   inflating: SzEbtbNSg04_214_224.npy
#   inflating: SzEbtbNSg04_28_48.npy
#   inflating: SzEbtbNSg04_70_85.npy
#   inflating: SzEbtbNSg04_71_93.npy
#   inflating: SzEbtbNSg04_88_93.npy
#   inflating: T6lPRKRpu9w_32_39.npy
#   inflating: TF6LNmwDr_0_2_10.npy
#   inflating: TFJ6oR89Vb8_90_107.npy
#   inflating: TIubRrkku-4_1_10.npy
#   inflating: TPD5wO_LEPU_2_6.npy
#   inflating: TPhpsIK7pDc_25_32.npy
#   inflating: TXabUVUxJqI_22_31.npy
#   inflating: TZ860P4iTaM_10_24.npy
#   inflating: TZ860P4iTaM_11_20.npy
#   inflating: TZ860P4iTaM_15_28.npy
#   inflating: Td29-SApubM_48_57.npy
#   inflating: TdYN7cePiRI_6_13.npy
#   inflating: Ted3imMggC0_48_58.npy
#   inflating: TgFmoZj3NoM_10_18.npy
#   inflating: Tied-t1fFsk_15_20.npy
#   inflating: TjLCJKoot4U_43_65.npy
#   inflating: Tm1HjqK0ABg_9_15.npy
#   inflating: TnPOZVHB3x0_45_55.npy
#   inflating: TsagxA4DKuc_28_41.npy
#   inflating: TvBsaMgqh5s_61_68.npy
#   inflating: TwQzFqBqgeA_0_10.npy
#   inflating: TxzxPyfsSxY_0_10.npy
#   inflating: UDwvax7K57c_28_35.npy
#   inflating: UI3Cbj9fbxQ_2_23.npy
#   inflating: UJKythlXAIY_17_21.npy
#   inflating: UXs3eq68ZjE_194_200.npy
#   inflating: UXs3eq68ZjE_209_214.npy
#   inflating: UXs3eq68ZjE_235_240.npy
#   inflating: UXs3eq68ZjE_246_250.npy
#   inflating: UXs3eq68ZjE_250_255.npy
#   inflating: UXs3eq68ZjE_255_260.npy
#   inflating: UXs3eq68ZjE_280_285.npy
#   inflating: UXs3eq68ZjE_313_318.npy
#   inflating: UXs3eq68ZjE_320_325.npy
#   inflating: UXs3eq68ZjE_382_387.npy
#   inflating: UXs3eq68ZjE_498_504.npy
#   inflating: UXs3eq68ZjE_49_54.npy
#   inflating: UXs3eq68ZjE_508_513.npy
#   inflating: UbmZAe5u5FI_101_110.npy
#   inflating: UbmZAe5u5FI_111_115.npy
#   inflating: UbmZAe5u5FI_132_141.npy
#   inflating: UbmZAe5u5FI_16_23.npy
#   inflating: UbmZAe5u5FI_26_33.npy
#   inflating: UbmZAe5u5FI_36_40.npy
#   inflating: UbmZAe5u5FI_44_55.npy
#   inflating: UbmZAe5u5FI_60_70.npy
#   inflating: UbmZAe5u5FI_88_98.npy
#   inflating: Uc63MFVwfrs_355_372.npy
#   inflating: Uc63MFVwfrs_360_372.npy
#   inflating: Ud3Qy8m6OxQ_52_62.npy
#   inflating: UdcObAQ5OOM_15_30.npy
#   inflating: UgUFP5baQ9Y_0_10.npy
#   inflating: UgUFP5baQ9Y_0_7.npy
#   inflating: Ugb_uH72d0I_8_17.npy
#   inflating: UhI-p6AysWY_25_30.npy
#   inflating: UnWgz-mVMXU_2_6.npy
#   inflating: UoPU8F9mus8_258_262.npy
#   inflating: UqBafx3iRKw_22_29.npy
#   inflating: UxhKb-zZoWE_0_15.npy
#   inflating: V--abChiVVc_30_40.npy
#   inflating: V4q5dQmpxIE_20_30.npy
#   inflating: V6Fxclwdfxc_1_11.npy
#   inflating: V6Fxclwdfxc_56_66.npy
#   inflating: VF1K_6ZSOAY_23_28.npy
#   inflating: VF1K_6ZSOAY_60_70.npy
#   inflating: VLBsAPZ2DDE_34_41.npy
#   inflating: VLBsAPZ2DDE_58_64.npy
#   inflating: VU4qLrk5axA_40_58.npy
#   inflating: VZ6H73nH7xs_27_33.npy
#   inflating: VahnQw2gTQY_203_210.npy
#   inflating: VahnQw2gTQY_274_280.npy
#   inflating: VahnQw2gTQY_288_293.npy
#   inflating: VahnQw2gTQY_298_305.npy
#   inflating: VahnQw2gTQY_315_320.npy
#   inflating: VahnQw2gTQY_322_327.npy
#   inflating: VfqlfprZsaQ_75_85.npy
#   inflating: Vg1jyL3cr60_163_186.npy
#   inflating: ViM0JjUoqRw_10_20.npy
#   inflating: ViWQUOGIaSU_9_16.npy
#   inflating: Vn0Xv0fb1z4_18_30.npy
#   inflating: VuCFgiWfVF4_0_6.npy
#   inflating: VxM96IYzw0Q_2_15.npy
#   inflating: VyBXcQ1v_cw_7_15.npy
#   inflating: W1052h2rzoA_91_98.npy
#   inflating: W20Btaww6zc_134_139.npy
#   inflating: W6_XuNhgtrM_2_5.npy
#   inflating: W8_63NiTENw_23_30.npy
#   inflating: W8l_ezoU8Lc_156_162.npy
#   inflating: W8l_ezoU8Lc_55_70.npy
#   inflating: W8l_ezoU8Lc_76_86.npy
#   inflating: WAa4-cctmDk_55_70.npy
#   inflating: WEJfT-oB4v4_20_35.npy
#   inflating: WFNXwor69-U_33_40.npy
#   inflating: WG0J2B19ZT8_1_33.npy
#   inflating: WPG-BIWOrG4_130_134.npy
#   inflating: WPG-BIWOrG4_608_613.npy
#   inflating: WPG-BIWOrG4_635_640.npy
#   inflating: WPG-BIWOrG4_672_677.npy
#   inflating: WPG-BIWOrG4_683_689.npy
#   inflating: WPG-BIWOrG4_755_761.npy
#   inflating: WTf5EgVY5uU_100_104.npy
#   inflating: WTf5EgVY5uU_104_108.npy
#   inflating: WTf5EgVY5uU_108_116.npy
#   inflating: WTf5EgVY5uU_121_135.npy
#   inflating: WTf5EgVY5uU_124_128.npy
#   inflating: WTf5EgVY5uU_130_135.npy
#   inflating: WTf5EgVY5uU_15_19.npy
#   inflating: WTf5EgVY5uU_16_24.npy
#   inflating: WTf5EgVY5uU_18_23.npy
#   inflating: WTf5EgVY5uU_218_236.npy
#   inflating: WTf5EgVY5uU_32_52.npy
#   inflating: WTf5EgVY5uU_33_39.npy
#   inflating: WTf5EgVY5uU_54_58.npy
#   inflating: WTf5EgVY5uU_58_76.npy
#   inflating: WTf5EgVY5uU_66_75.npy
#   inflating: WTf5EgVY5uU_76_83.npy
#   inflating: WTf5EgVY5uU_94_98.npy
#   inflating: WTf5EgVY5uU_98_104.npy
#   inflating: WTx-K045yQM_85_98.npy
#   inflating: WV9K6MbLjHA_106_116.npy
#   inflating: WWf0Z6ak3Dg_5_15.npy
#   inflating: WZTGqvbqOFE_28_34.npy
#   inflating: W_iR4YVCxUY_8_15.npy
#   inflating: WeOU0Iba1Xg_1_30.npy
#   inflating: WinaH9SkW9c_11_38.npy
#   inflating: Wnz3IevSNg0_1_8.npy
#   inflating: WpB4-eLyiBc_10_20.npy
#   inflating: WqQonRVs7WA_0_10.npy
#   inflating: WqwcWk1In_g_46_54.npy
#   inflating: WrsS6X-FB-I_30_47.npy
#   inflating: Wv3u2q3oGeU_35_45.npy
#   inflating: WyIqGyj21Dk_0_10.npy
#   inflating: X0UJaprpxrk_18_26.npy
#   inflating: X4yzrIc072w_4_20.npy
#   inflating: X56XkGFe7OY_47_61.npy
#   inflating: X6uJyuD_Zso_3_17.npy
#   inflating: X7sQq-Iu1gQ_12_22.npy
#   inflating: X98fLZHIzWQ_15_20.npy
#   inflating: XEOH3t5AYY0_22_29.npy
#   inflating: XNV7hKVu-Xg_40_47.npy
#   inflating: XNzXXiE6qR4_0_10.npy
#   inflating: XOAgUVVwKEA_8_20.npy
#   inflating: XZ0Ch_ClBfo_120_127.npy
#   inflating: X_NLV2KCnIE_60_70.npy
#   inflating: XdB0pVjFYoU_1_8.npy
#   inflating: Xh6rdpJNaf0_0_15.npy
#   inflating: Xp6rxW4hFFo_32_40.npy
#   inflating: XtQdAPV2UZs_4_11.npy
#   inflating: Xvy21KrDv8I_0_10.npy
#   inflating: Xwrl4htUPjo_22_38.npy
#   inflating: Xxcv5jvRmcg_39_46.npy
#   inflating: XzCcRzEa83U_1_8.npy
#   inflating: XzCcRzEa83U_39_46.npy
#   inflating: Y4BeJ-64294_20_30.npy
#   inflating: Y4gaJn0wlDE_0_10.npy
#   inflating: YAud4eS3DoA_54_65.npy
#   inflating: YEmS8ZQIhTA_7_20.npy
#   inflating: YJ2aGe7CLBo_25_35.npy
#   inflating: YRSOc193Pxc_68_73.npy
#   inflating: YS1mzzhmWWA_9_16.npy
#   inflating: YUlG_PKzpvc_0_8.npy
#   inflating: YXixZrSxefk_17_48.npy
#   inflating: YXixZrSxefk_49_59.npy
#   inflating: YXixZrSxefk_6_15.npy
#   inflating: YZ0-6hdQ0mU_0_3.npy
#   inflating: Ya-MkA187c8_36_45.npy
#   inflating: YersIyzsOpc_15_30.npy
#   inflating: Yh2N6ZtRBdU_110_120.npy
#   inflating: Ylb4pnW-jP4_102_113.npy
#   inflating: YmXCfQm0_CA_109_120.npy
#   inflating: YmXCfQm0_CA_140_156.npy
#   inflating: YmXCfQm0_CA_277_284.npy
#   inflating: YmXCfQm0_CA_50_57.npy
#   inflating: YmXCfQm0_CA_68_75.npy
#   inflating: YmXCfQm0_CA_7_16.npy
#   inflating: YndZ9YulpTo_61_76.npy
#   inflating: YwmUgVrUJ4I_0_15.npy
#   inflating: Z-An1QQ66f0_13_25.npy
#   inflating: Z10_CDPQKKs_1_6.npy
#   inflating: Z19zFlPah-o_6_11.npy
#   inflating: Z3XarHZ3HpY_10_17.npy
#   inflating: Z3m9V8qPXhQ_13_24.npy
#   inflating: Z3rj9LbCOaM_0_12.npy
#   inflating: Z8rTzW9Gb6Y_116_123.npy
#   inflating: ZDoy9S82ETA_5_15.npy
#   inflating: ZK4W-2ifl6I_1_28.npy
#   inflating: ZL7P_XmSnEY_205_209.npy
#   inflating: ZN2_czSBSD0_240_250.npy
#   inflating: ZYaxg5NZW_g_21_27.npy
#   inflating: ZbtpcGi2DWY_161_170.npy
#   inflating: ZbtpcGi2DWY_56_62.npy
#   inflating: ZbzDGXEwtGc_6_15.npy
#   inflating: ZdNP0dXCx2I_78_90.npy
#   inflating: ZdlG8fjGJlo_78_87.npy
#   inflating: Zg0p5TXi_Cc_30_46.npy
#   inflating: ZlX_Gy4HP2E_38_55.npy
#   inflating: ZnLgsasu82g_71_81.npy
#   inflating: Zoz0HcCB1vU_0_10.npy
#   inflating: Zqmx-nXhLAg_0_10.npy
#   inflating: ZsrPKtx0qyg_7_15.npy
#   inflating: ZvJvNcukZ4w_0_10.npy
#   inflating: ZxqkAGNyo8A_12_22.npy
#   inflating: _0nX-El-ySo_83_93.npy
#   inflating: _1vy2HIN60A_32_40.npy
#   inflating: _6OTzzK7t9Y_158_170.npy
#   inflating: _6OTzzK7t9Y_73_78.npy
#   inflating: _7nP9z6T9m8_11_17.npy
#   inflating: _9iG5Ge01PM_3_11.npy
#   inflating: _JVxurtGIhI_32_42.npy
#   inflating: _JorUS-8Nlg_63_73.npy
#   inflating: _KMoC6ZdeXs_10_16.npy
#   inflating: _O9kWD8nuRU_16_23.npy
#   inflating: _O9kWD8nuRU_25_35.npy
#   inflating: _O9kWD8nuRU_37_43.npy
#   inflating: _O9kWD8nuRU_45_49.npy
#   inflating: _O9kWD8nuRU_50_56.npy
#   inflating: _O9kWD8nuRU_70_76.npy
#   inflating: _O9kWD8nuRU_77_81.npy
#   inflating: _OBlgSz8sSM_15_32.npy
#   inflating: _QJbjKkfdcs_52_57.npy
#   inflating: _SNE2MYAotU_41_49.npy
#   inflating: _UqnTFs1BLc_23_27.npy
#   inflating: _WRC7HXBJpU_360_370.npy
#   inflating: _WRC7HXBJpU_386_391.npy
#   inflating: _WRC7HXBJpU_395_401.npy
#   inflating: _WRC7HXBJpU_414_425.npy
#   inflating: _WRC7HXBJpU_451_464.npy
#   inflating: _ZwwKOzpt2I_69_76.npy
#   inflating: _o1UXSxTjfo_68_80.npy
#   inflating: _pBeOAMjGm8_1_18.npy
#   inflating: _pj2Nutu5v8_1_8.npy
#   inflating: _sJ_09Mf1HY_49_72.npy
#   inflating: _txL575S_OA_13_23.npy
#   inflating: _xf24TYgbuY_14_20.npy
#   inflating: _yUiusXxfWI_150_165.npy
#   inflating: a-cek0mvXxE_15_25.npy
#   inflating: a0g7wtBkS98_34_42.npy
#   inflating: a1Y73sPHKxw_0_5.npy
#   inflating: a1i6T160REQ_5_18.npy
#   inflating: a28s_wyqkyc_68_77.npy
#   inflating: a8PAY4rvzRM_1_10.npy
#   inflating: aA05I5QaZnM_66_75.npy
#   inflating: aC-KOYQsIvU_25_31.npy
#   inflating: aCKNdip53W4_0_25.npy
#   inflating: aDjNl5gs4nM_18_47.npy
#   inflating: aGUx0QOKWXw_7_12.npy
#   inflating: aHiUM8uWxxo_17_25.npy
#   inflating: aJoDt4DMkFU_118_124.npy
#   inflating: aK8liAv-28s_72_82.npy
#   inflating: aM-RcQj0a7I_37_55.npy
#   inflating: aN0WsBcja_E_0_15.npy
#   inflating: aQWCKcg0VRU_321_339.npy
#   inflating: aRo8x3xXeEA_3_8.npy
#   inflating: aeA-HN7BMdo_16_33.npy
#   inflating: aeA-HN7BMdo_34_41.npy
#   inflating: aeA-HN7BMdo_52_58.npy
#   inflating: akXjIEoecNs_2_12.npy
#   inflating: ao-9B8IV9_E_108_119.npy
#   inflating: ao-9B8IV9_E_175_187.npy
#   inflating: ao-9B8IV9_E_217_221.npy
#   inflating: ao-9B8IV9_E_37_44.npy
#   inflating: ao-9B8IV9_E_72_77.npy
#   inflating: ao-9B8IV9_E_77_81.npy
#   inflating: ao-9B8IV9_E_87_95.npy
#   inflating: auFXfsCzAvQ_1_15.npy
#   inflating: b-d-CxHaKGU_10_30.npy
#   inflating: b24_bb57PPk_631_637.npy
#   inflating: b4FM9OLBGyM_37_49.npy
#   inflating: b4mJ3AQc-ag_30_34.npy
#   inflating: b71bI0rH1g8_75_90.npy
#   inflating: b97TK8XVLHE_40_50.npy
#   inflating: bAYIIlX-WWw_5_15.npy
#   inflating: bDoCQEwghZU_201_211.npy
#   inflating: bJJndejsUWc_88_98.npy
#   inflating: bK-i_FAcpoY_86_92.npy
#   inflating: bL_Kijz9IN4_0_15.npy
#   inflating: bLqmf8x7rLI_2_8.npy
#   inflating: bQJQGoJF7_k_109_115.npy
#   inflating: bQJQGoJF7_k_120_126.npy
#   inflating: bQJQGoJF7_k_145_153.npy
#   inflating: bQJQGoJF7_k_162_169.npy
#   inflating: bSIjZ75a50s_286_304.npy
#   inflating: bSrpvMSuhPM_17_31.npy
#   inflating: bXsKw3TOQXs_30_55.npy
#   inflating: b_BuSVZwq6M_1_9.npy
#   inflating: bb6V0Grtub4_174_185.npy
#   inflating: bkazguPsusc_74_85.npy
#   inflating: bmOy6p87TWI_26_35.npy
#   inflating: bmvD4HlPFxg_20_27.npy
#   inflating: bmxIurBrW5s_51_70.npy
#   inflating: bnN_o0Hkn3M_73_80.npy
#   inflating: bqMmyY1ImkI_0_14.npy
#   inflating: bruzcOyIGeg_4_12.npy
#   inflating: btuxO-C2IzE_64_72.npy
#   inflating: btxCxlO1Euc_1_20.npy
#   inflating: buJ5HDCinrM_150_166.npy
#   inflating: bxDlC7YV5is_0_12.npy
#   inflating: bxjFqtfJlMs_18_27.npy
#   inflating: c2MwqFYVE7A_40_45.npy
#   inflating: c2a0GcoJAjw_107_129.npy
#   inflating: c2a0GcoJAjw_52_73.npy
#   inflating: c51L6ZxZGjQ_137_154.npy
#   inflating: c53HKs39i28_26_35.npy
#   inflating: c75SIlAjfjg_6_14.npy
#   inflating: c76tShLfQb0_74_81.npy
#   inflating: cCmnN96zIeQ_14_24.npy
#   inflating: cFzSEIGrEfA_0_24.npy
#   inflating: cJOZp2ZftCw_1_12.npy
#   inflating: cLNrpO6wBk4_37_47.npy
#   inflating: cM55xNJ_pfU_1_20.npy
#   inflating: cR2yi-JnGcQ_8_16.npy
#   inflating: cSDkshD2ME0_11_14.npy
#   inflating: cSDkshD2ME0_12_15.npy
#   inflating: cUW_bXll6YM_390_395.npy
#   inflating: cUW_bXll6YM_462_469.npy
#   inflating: cWOPC2kt_IA_8_16.npy
#   inflating: c_-eFL7Sfw4_19_35.npy
#   inflating: c_XV7nPoRg8_2_12.npy
#   inflating: ceOXCFUmxzA_100_110.npy
#   inflating: clKtfGBVI1I_15_28.npy
#   inflating: clpgffj3sUw_1_12.npy
#   inflating: cmQ3SiIaWy4_4_20.npy
#   inflating: cnsjm3fNEec_4_10.npy
#   inflating: crfrKqFp0Zg_15_25.npy
#   inflating: cs33MNhpRNw_16_21.npy
#   inflating: cwkjJrGpoaU_30_41.npy
#   inflating: d-2C_N5anww_1_3.npy
#   inflating: d1zdJO3CqVw_1_35.npy
#   inflating: d4AGWnHJcaY_6_19.npy
#   inflating: d7Gs0uGFLh0_5_13.npy
#   inflating: d7eGypGOlOc_13_22.npy
#   inflating: dEn5E-TNezw_13_23.npy
#   inflating: dJ3ba9zwx6c_5_15.npy
# ...
#   inflating: m1NR0uNNs5Y_57_64.npy
#   inflating: m1NR0uNNs5Y_73_78.npy
#   inflating: m1NR0uNNs5Y_88_94.npy
#   inflating: m1c04pCYGxA_57_64.npy
#   inflating: m4D72WXFd8s_557_564.npy
#   inflating: m7x8uIdg2XU_67_73.npy
#   inflating: mCrRHP4LFmo_24_40.npy
#   inflating: mF6ijhSrbBQ_32_40.npy
#   inflating: mFCf8lLXrUc_25_35.npy
#   inflating: mFCf8lLXrUc_36_57.npy
#   inflating: mHv4iJ9Yr1g_10_16.npy
#   inflating: mJ9eRvxjLc4_0_16.npy
#   inflating: mOZkcBcWR8o_6_12.npy
#   inflating: mYzajpeAWuA_100_112.npy
#   inflating: mZVPkPqwzR4_38_45.npy
#   inflating: mbesJaS6vwg_187_195.npy
#   inflating: me1D1WZ0yNM_120_124.npy
#   inflating: mfJjIOfj6D8_3_10.npy
#   inflating: mmSQTI6gMNQ_120_128.npy
#   inflating: mmSQTI6gMNQ_15_21.npy
#   inflating: msCidKHOh74_392_399.npy
#   inflating: msCidKHOh74_410_418.npy
#   inflating: mtrCf667KDk_134_176.npy
#   inflating: muI1BFsdbdo_33_45.npy
#   inflating: mv89psg6zh4_33_46.npy
#   inflating: n016q1w8Q30_2_11.npy
#   inflating: n2NLoLNecgI_168_178.npy
#   inflating: n6U-TGahwvs_100_110.npy
#   inflating: nBFhvrAOFqY_23_29.npy
#   inflating: nBFhvrAOFqY_89_103.npy
#   inflating: nBJV56WUDng_38_47.npy
#   inflating: nCtZFOYAlvQ_44_49.npy
#   inflating: nHZsE7T7hwI_13_23.npy
#   inflating: nLvX-erABqY_67_72.npy
#   inflating: nLz0QuerH1c_8_15.npy
#   inflating: nMBSDpB3WB8_5_14.npy
#   inflating: nPj6EcVGoUY_7_15.npy
#   inflating: nS6oQxX_Qi8_2_12.npy
#   inflating: nTUONeDqhdk_10_15.npy
#   inflating: nTasT5h0LEg_12_14.npy
#   inflating: nTasT5h0LEg_40_43.npy
#   inflating: nULE40HEWpA_5_11.npy
#   inflating: nV3Wv8iHp4U_0_38.npy
#   inflating: nYwbAb0QvBE_195_210.npy
#   inflating: nZSFn51l3hc_318_326.npy
#   inflating: nZSFn51l3hc_480_485.npy
#   inflating: nZSFn51l3hc_660_666.npy
#   inflating: n_Z0-giaspE_168_193.npy
#   inflating: n_Z0-giaspE_270_278.npy
#   inflating: n_Z0-giaspE_379_387.npy
#   inflating: n_Z0-giaspE_437_447.npy
#   inflating: n_Z0-giaspE_62_78.npy
#   inflating: nau1vCzyFQ4_37_54.npy
#   inflating: nb12bAaKzvA_0_10.npy
#   inflating: nc0fVlaTYEs_34_44.npy
#   inflating: nc8hwLaOyZU_1_19.npy
#   inflating: nd0ToNwccl4_12_17.npy
#   inflating: ngHDYzhDBk4_24_29.npy
#   inflating: ngHDYzhDBk4_5_14.npy
#   inflating: nhm_APPwhWk_6_12.npy
#   inflating: nlU3crMsbWI_19_23.npy
#   inflating: nohvigNMsbo_199_207.npy
#   inflating: nq4hG6qgyPs_184_195.npy
#   inflating: nq4hG6qgyPs_240_251.npy
#   inflating: nq4hG6qgyPs_370_377.npy
#   inflating: nrZyPuRd5pU_85_92.npy
#   inflating: nwk4m329bLw_2_10.npy
#   inflating: o2X6UCaNqKA_27_36.npy
#   inflating: o4OsYxsNGMI_77_82.npy
#   inflating: o4pL7FObqds_137_147.npy
#   inflating: o4pL7FObqds_243_263.npy
#   inflating: o4pL7FObqds_72_78.npy
#   inflating: oBt257I-pL0_0_10.npy
#   inflating: oDcd2JbOyzg_38_55.npy
#   inflating: oDcd2JbOyzg_85_98.npy
#   inflating: oFUsn1owAbs_158_168.npy
#   inflating: oG6LLGi_n48_51_55.npy
#   inflating: oRBgVOiZVsc_16_22.npy
#   inflating: oSnYUfCGiCA_7_17.npy
#   inflating: o_mWZWcm2r4_10_15.npy
#   inflating: o_mWZWcm2r4_47_54.npy
#   inflating: oeaVXK2GAyc_4_21.npy
#   inflating: ogcqFaNbah4_475_487.npy
#   inflating: ok4cM6WTA5E_120_133.npy
#   inflating: ok4cM6WTA5E_142_150.npy
#   inflating: ok4cM6WTA5E_178_184.npy
#   inflating: omGWjiwxcTE_18_23.npy
#   inflating: omIPdpxg--4_39_46.npy
#   inflating: onW5hJXnI5s_10_16.npy
#   inflating: onW5hJXnI5s_126_133.npy
#   inflating: onxE6PpEXes_8_25.npy
#   inflating: otLEUwHao_E_140_151.npy
#   inflating: otvx5OZHTJc_1_22.npy
#   inflating: p3J3TAdKAYQ_0_10.npy
#   inflating: p69Q8lTkZTc_21_29.npy
#   inflating: p69d3UBdpR8_98_109.npy
#   inflating: p6T3XrnYtFk_4_13.npy
#   inflating: p6cg2jWI34M_34_42.npy
#   inflating: p7IAuvd87hQ_12_19.npy
#   inflating: p9g06ktIkJg_4_11.npy
#   inflating: pDvzOLRLjPc_0_8.npy
#   inflating: pFSoWsocv0g_8_17.npy
#   inflating: pGCRurvXQGM_45_56.npy
#   inflating: pGsU4FekJQM_10_18.npy
#   inflating: pNelR-nHz7g_68_90.npy
#   inflating: pQYEZTwSVbQ_12_18.npy
#   inflating: pRpeEdMmmQ0_1_18.npy
#   inflating: pRpeEdMmmQ0_65_70.npy
#   inflating: pUPKsHTDZTo_70_85.npy
#   inflating: pW9DFPqoIsI_26_50.npy
#   inflating: pcjuCotJYj8_50_62.npy
#   inflating: pdrBPJYfTC8_33_39.npy
#   inflating: pfQPRXcihkI_127_138.npy
#   inflating: pfQPRXcihkI_135_144.npy
#   inflating: pfQPRXcihkI_160_184.npy
#   inflating: pmEKZ6yVewc_0_10.npy
#   inflating: po2tcrG6KzM_2_8.npy
#   inflating: pptYu3YQnxY_160_170.npy
#   inflating: pqTWUzehCUM_42_47.npy
#   inflating: psXeA8sSYdI_25_30.npy
#   inflating: ptHkvYrH9fY_2_10.npy
#   inflating: puineN1UMto_25_29.npy
#   inflating: pzq5fPfsPZg_145_160.npy
#   inflating: pzq5fPfsPZg_29_33.npy
#   inflating: pzq5fPfsPZg_51_57.npy
#   inflating: q-JHcsqJXWY_0_8.npy
#   inflating: q-a6NEotUX8_5_10.npy
#   inflating: q3I3R_gqy8M_34_37.npy
#   inflating: q3I3R_gqy8M_38_42.npy
#   inflating: q3I3R_gqy8M_73_79.npy
#   inflating: q5ZRMvjzhXQ_15_29.npy
#   inflating: q6vz80UkVtw_0_7.npy
#   inflating: q7pOFn8s4zc_263_273.npy
#   inflating: q7pOFn8s4zc_27_36.npy
#   inflating: q8t7iSGAKik_11_31.npy
#   inflating: q8t7iSGAKik_57_74.npy
#   inflating: q9ew_nITQWY_54_62.npy
#   inflating: qBFSt85-xqk_15_20.npy
#   inflating: qDjtN7xxNr4_44_51.npy
#   inflating: qIXs7fUoLIg_1_11.npy
#   inflating: qIk_Dz5XE5E_104_109.npy
#   inflating: qLwgb3F0aPU_298_305.npy
#   inflating: qNjeEx92rTA_281_299.npy
#   inflating: qOiN__I1-Zo_2_8.npy
#   inflating: qPXynwa_2iM_15_25.npy
#   inflating: qRoxNXm7INc_58_66.npy
#   inflating: qeKX-N1nKiM_0_5.npy
#   inflating: qeKX-N1nKiM_106_115.npy
#   inflating: qeKX-N1nKiM_123_130.npy
#   inflating: qeKX-N1nKiM_133_142.npy
#   inflating: qeKX-N1nKiM_37_43.npy
#   inflating: qeKX-N1nKiM_52_59.npy
#   inflating: qeKX-N1nKiM_68_72.npy
#   inflating: qeKX-N1nKiM_74_77.npy
#   inflating: qew09qQgMAg_22_27.npy
#   inflating: qhknaG9ifbs_122_127.npy
#   inflating: qqYysi3qotc_148_195.npy
#   inflating: qvSxiVV7jhw_0_15.npy
#   inflating: qvg9eM4Hmzk_1_9.npy
#   inflating: qvg9eM4Hmzk_4_10.npy
#   inflating: qypmR4O1Gwk_0_10.npy
#   inflating: qzQzooI4BqU_5_15.npy
#   inflating: r0E-0ntoNWo_20_30.npy
#   inflating: r0rmrbTb7fU_98_109.npy
#   inflating: r2PM0om2El8_18_25.npy
#   inflating: r2oI9Y-3wAo_21_28.npy
#   inflating: r4qv_BNlQNk_119_124.npy
#   inflating: r4qv_BNlQNk_93_98.npy
#   inflating: rKF0ZW34FRk_41_54.npy
#   inflating: rNSAmHPYHjA_60_73.npy
#   inflating: rOic25PnIx8_1_3.npy
#   inflating: rQuNYxNmA6M_0_4.npy
#   inflating: rV5VmhY3-Sw_65_76.npy
#   inflating: rVFJzN20jhQ_27_32.npy
#   inflating: rXZy-PHtnxg_8_42.npy
#   inflating: ri5AyXzxb4o_201_215.npy
#   inflating: rl1rVk_xIOs_1_16.npy
#   inflating: rlQ2kW-FvMk_66_79.npy
#   inflating: rnawC5C8gSI_82_90.npy
#   inflating: rq2p5ML8-WI_63_69.npy
#   inflating: ruNrdmjcNTc_0_5.npy
#   inflating: ruoHOXo2PRQ_2_20.npy
#   inflating: rw9h_574HxE_127_133.npy
#   inflating: rw9h_574HxE_13_18.npy
#   inflating: rw9h_574HxE_161_166.npy
#   inflating: rw9h_574HxE_229_236.npy
#   inflating: rw9h_574HxE_251_254.npy
#   inflating: rw9h_574HxE_59_66.npy
#   inflating: rw9h_574HxE_70_74.npy
#   inflating: rwHT2SuNOi8_195_201.npy
#   inflating: rwHT2SuNOi8_240_255.npy
#   inflating: ry7AUQtuwdU_4_39.npy
#   inflating: s-QQWRdF-5Y_19_28.npy
#   inflating: s-XjRDsYuzU_0_12.npy
#   inflating: s-dSFyz_5Ww_13_23.npy
#   inflating: s-dSFyz_5Ww_31_41.npy
#   inflating: s0hwEUC5emA_127_132.npy
#   inflating: s1ZABV7AQdA_38_48.npy
#   inflating: s20OlIRK340_125_138.npy
#   inflating: s20OlIRK340_147_174.npy
#   inflating: s6QwbmWbSmw_18_24.npy
#   inflating: s7znbqra118_91_97.npy
#   inflating: s80J2dAUUyI_33_43.npy
#   inflating: s8utHZYTNTs_35_42.npy
#   inflating: s9TklvyLFyI_177_191.npy
#   inflating: sBjr8UJOpsQ_149_169.npy
#   inflating: sBjr8UJOpsQ_181_195.npy
#   inflating: sFExO_PW22s_10_18.npy
#   inflating: sJC7E06IBXI_49_59.npy
#   inflating: sJSmRik2c-c_1_7.npy
#   inflating: sMscRb9TcQE_146_161.npy
#   inflating: sRKQfxxEP4M_117_125.npy
#   inflating: sT5Bzt9w354_11_34.npy
#   inflating: sTMlQSbAGfE_0_12.npy
#   inflating: sWqi41wyXcQ_68_79.npy
#   inflating: sXyjCgR0rAc_0_11.npy
#   inflating: sZf3VDsdDPM_107_114.npy
#   inflating: s_ldnx8_etY_32_54.npy
#   inflating: sb1dX5xAFvk_10_17.npy
#   inflating: seTkGZlEU64_81_110.npy
#   inflating: shPymuahrsc_5_12.npy
#   inflating: sm0OYD0NSbQ_51_59.npy
#   inflating: suj4VNfZz5E_33_50.npy
#   inflating: sv5YlZspb30_10_20.npy
#   inflating: swJ0zhVJ8DU_15_21.npy
#   inflating: swKrHEeOj9c_4_8.npy
#   inflating: t3VPeyYL-fI_35_39.npy
#   inflating: t4aPGtx7e6k_0_10.npy
#   inflating: t4vP-cXXWkY_14_20.npy
#   inflating: t8Nf1MK7lts_0_10.npy
#   inflating: tBj4Ny19vfQ_54_59.npy
#   inflating: tHLiYTS9Iz8_1_16.npy
#   inflating: tIMDKdMnNYM_266_273.npy
#   inflating: tJHUH9tpqPg_113_118.npy
#   inflating: tPkZK-PzeQE_10_28.npy
#   inflating: tYQ7O6V0Fvk_20_55.npy
#   inflating: tYh4iDFgmEE_10_14.npy
#   inflating: tYh4iDFgmEE_50_54.npy
#   inflating: tZmDWltBziM_42_47.npy
#   inflating: tZmDWltBziM_70_80.npy
#   inflating: tcxhOGyrCtI_15_21.npy
#   inflating: tmAX2PnRCY0_284_292.npy
#   inflating: tn-Hoz4KbkE_89_93.npy
#   inflating: tn1d5DmdMqY_15_28.npy
#   inflating: toE0QYZzJKE_1_8.npy
#   inflating: tqxRDVKtkSY_30_45.npy
#   inflating: tzd3AYTZq0U_0_6.npy
#   inflating: u4T76jsPin0_0_11.npy
#   inflating: u4kMN1jamdM_10_20.npy
#   inflating: u9E9HpuJQ7U_29_43.npy
#   inflating: u9prcUCHlqM_235_241.npy
#   inflating: u9prcUCHlqM_503_511.npy
#   inflating: u9prcUCHlqM_73_80.npy
#   inflating: uAaWVeaYLdQ_1_12.npy
#   inflating: uB9zRlV47qA_17_23.npy
#   inflating: uGDuIyfJXXg_23_33.npy
#   inflating: uH8ObB_dyOk_159_166.npy
#   inflating: uJPupV4oLZ0_4_12.npy
#   inflating: uO7Eysrs8_k_106_114.npy
#   inflating: uO7Eysrs8_k_80_90.npy
#   inflating: uVPnDJKt1M0_0_6.npy
#   inflating: uZEGu-TA2cU_42_58.npy
#   inflating: u_6tre9_99Q_13_25.npy
#   inflating: ub-aYLzCF_Q_1_10.npy
#   inflating: ufFT2BWh3BQ_0_8.npy
#   inflating: uiLr9bdOL0M_23_30.npy
#   inflating: ul9Xvjt83eI_111_120.npy
#   inflating: ulPvRmNfXK4_96_100.npy
#   inflating: umjc1CkO4JA_290_305.npy
#   inflating: unhiT2D6WvE_0_20.npy
#   inflating: uppFvcVwqqY_5_15.npy
#   inflating: uqVCk2oDpSE_194_200.npy
#   inflating: urNX3e1Wbc8_30_38.npy
#   inflating: urXDqw3S34I_12_17.npy
#   inflating: uxEhH6MPH28_69_85.npy
#   inflating: uy0HNWto0UY_18_25.npy
#   inflating: v-9Gx0gJmfo_26_32.npy
#   inflating: v-9Gx0gJmfo_91_99.npy
#   inflating: v4_AzQSnmY4_40_55.npy
#   inflating: v5CeGLEnVFE_0_8.npy
#   inflating: v7NpKUVqjpI_23_40.npy
#   inflating: v7iIZXtpIb8_5_15.npy
#   inflating: vDhEpqfhVI0_0_8.npy
#   inflating: vE1gvaM3iAs_39_46.npy
#   inflating: vMoOpQQy6sI_22_55.npy
#   inflating: vRC9sBNt9vs_10_16.npy
#   inflating: vZa13vJugGU_0_30.npy
#   inflating: v_tGw5gwlEw_136_152.npy
#   inflating: veE0E79dEEc_18_45.npy
#   inflating: vfktGc_qx-w_2_18.npy
#   inflating: vloe_60s_dk_0_9.npy
#   inflating: vpR0L3sIvoo_15_49.npy
#   inflating: vub04F8CWng_32_41.npy
#   inflating: vulNlhUI6m0_7_27.npy
#   inflating: vuvpbeQak9Q_23_29.npy
#   inflating: vz71JKcpeUU_0_10.npy
#   inflating: w28TljSqtW8_64_75.npy
#   inflating: w9mqbwOIkVg_6_12.npy
#   inflating: wFPmKChNrhU_3_11.npy
#   inflating: wFX6bXLbHW4_83_90.npy
#   inflating: wLUH7qA_6sA_90_115.npy
#   inflating: wNv74rvkAw8_30_40.npy
#   inflating: wON-YuA1GjA_3_63.npy
#   inflating: wSwwS_0MKEc_68_78.npy
#   inflating: wX-Bl25Htag_104_115.npy
#   inflating: wgrrQwLdME8_0_10.npy
#   inflating: wgrrQwLdME8_66_74.npy
#   inflating: wjH72cZ0GLM_1_10.npy
#   inflating: wkgGxsuNVSg_34_41.npy
#   inflating: wn9rDTZj-m4_8_18.npy
#   inflating: wpUT0DNB3qs_9_19.npy
#   inflating: wsj_dzz33Ko_31_41.npy
#   inflating: wzfkC2TjdeQ_0_31.npy
#   inflating: x1i0UOssll8_141_151.npy
#   inflating: x68Djm_Q0GA_0_10.npy
#   inflating: x8Ul09tk6zk_0_8.npy
#   inflating: xBW_uR3kGr4_42_55.npy
#   inflating: xBePrplM4OA_6_18.npy
#   inflating: xCFCXzDUGjY_5_9.npy
#   inflating: xEDCfcMZlZY_37_41.npy
#   inflating: xEDCfcMZlZY_91_100.npy
#   inflating: xGdoi3W3Z4o_2_40.npy
#   inflating: xOQn1z_oWDY_30_39.npy
#   inflating: xPR0xFgCAZY_17_27.npy
#   inflating: xSmfK498DjI_1_20.npy
#   inflating: xTd_IdIcB4s_2_10.npy
#   inflating: xXlWsBhFvis_6_10.npy
#   inflating: x_7BrCQdVUs_172_177.npy
#   inflating: x_8RiVI6rH8_41_54.npy
#   inflating: xaPepCVepCg_35_46.npy
#   inflating: xb-Nacm-pKc_78_82.npy
#   inflating: xdhLQCYQ-nQ_50_63.npy
#   inflating: xfRIRSWy0y0_10_20.npy
#   inflating: xgIIcPSh4EU_0_6.npy
#   inflating: xkNDE1JL6Z8_50_59.npy
#   inflating: xlPyHMkpaQY_1_7.npy
#   inflating: xpOYXbMDDBY_1_20.npy
#   inflating: xtbsD3PUua4_174_185.npy
#   inflating: xtbsD3PUua4_84_94.npy
#   inflating: xxHx6s_DbUo_121_128.npy
#   inflating: xxHx6s_DbUo_158_161.npy
#   inflating: xxHx6s_DbUo_162_165.npy
#   inflating: xxHx6s_DbUo_173_177.npy
#   inflating: xxHx6s_DbUo_182_186.npy
#   inflating: xxHx6s_DbUo_202_207.npy
#   inflating: xxHx6s_DbUo_216_222.npy
#   inflating: xxHx6s_DbUo_240_248.npy
#   inflating: xxHx6s_DbUo_32_36.npy
#   inflating: xxHx6s_DbUo_36_40.npy
#   inflating: xxHx6s_DbUo_41_44.npy
#   inflating: xxHx6s_DbUo_49_56.npy
#   inflating: xxHx6s_DbUo_57_61.npy
#   inflating: xxHx6s_DbUo_82_86.npy
#   inflating: xxHx6s_DbUo_98_101.npy
#   inflating: xy9LLUUZ6ic_50_60.npy
#   inflating: y8SDRc4IOjs_94_99.npy
#   inflating: yAD_TS5L2d4_4_11.npy
#   inflating: yBK02O1Oewc_20_35.npy
#   inflating: yC4eEuURH8c_19_28.npy
#   inflating: yFPHhRat6bc_160_210.npy
#   inflating: yId1rg5-ac0_40_50.npy
#   inflating: yNy9jTeolUk_8_12.npy
#   inflating: yOnRm3TP6hM_0_12.npy
#   inflating: yPNFVj-pISU_105_115.npy
#   inflating: yREFkmrrYiw_51_57.npy
#   inflating: yU5sxW9bErQ_0_17.npy
#   inflating: yYA7YXIKbg4_9_14.npy
#   inflating: ybVb3t560oY_0_9.npy
#   inflating: yd8jh9QYfEs_4_10.npy
#   inflating: yfMTsYcLt10_0_7.npy
#   inflating: yg4aNiO1JnI_111_114.npy
#   inflating: ymC2bNi6-Is_9_19.npy
#   inflating: ysTmUTQ5wZE_17_45.npy
#   inflating: yvfhk1kwKls_103_113.npy
#   inflating: ywHBKayhyvQ_19_28.npy
#   inflating: ywMLb2VfHbI_13_20.npy
#   inflating: yyxtyCaEVqk_250_264.npy
#   inflating: yyxtyCaEVqk_321_328.npy
#   inflating: yyxtyCaEVqk_329_360.npy
#   inflating: z0Si1XxMibg_0_30.npy
#   inflating: z0zb--BOhDY_16_22.npy
#   inflating: z1PEyzk4ADU_8_18.npy
#   inflating: z2kUc8wp9l8_40_46.npy
#   inflating: z8dcUzdi2bw_3_16.npy
#   inflating: z9qbQX4J_2g_0_14.npy
#   inflating: zBrC1GmA0Qg_26_33.npy
#   inflating: zCf8NWJ8kzA_47_52.npy
#   inflating: zFIn8DeV5PM_20_33.npy
#   inflating: zH4v_DClIoc_3_28.npy
#   inflating: zHy7pM0U49w_103_109.npy
#   inflating: zHy7pM0U49w_110_116.npy
#   inflating: zMg9dChF97A_12_38.npy
#   inflating: zS50h-a8RTg_3_9.npy
#   inflating: zSPBC8EO6dY_122_126.npy
#   inflating: zSPBC8EO6dY_132_140.npy
#   inflating: zSPBC8EO6dY_64_73.npy
#   inflating: zSPBC8EO6dY_97_110.npy
#   inflating: zTn-nNj5Bng_61_77.npy
#   inflating: zTn-nNj5Bng_8_19.npy
#   inflating: zWVQImPY2Cc_27_44.npy
#   inflating: zYcY4mjLpxU_104_118.npy
#   inflating: zYcY4mjLpxU_45_55.npy
#   inflating: z_qf7tOnHVg_81_89.npy
#   inflating: za-9mBZyNfQ_330_336.npy
#   inflating: zbAk0gX7kas_16_24.npy
#   inflating: zfQOH4UGU_I_1_10.npy
#   inflating: zhLcONtNkew_16_21.npy
#   inflating: zkTn5Ef1Oig_70_75.npy
#   inflating: zkTn5Ef1Oig_71_75.npy
#   inflating: zlS1_zBYluY_15_21.npy
#   inflating: zpgW7m7_LZw_2_15.npy
#   inflating: zr9OeyfLPPY_4_9.npy
#   inflating: zuYZ5kPatJE_78_116.npy
#   inflating: zulPFoY64wE_26_33.npy
#   inflating: zv2RIbUsnSw_159_162.npy
#   inflating: zv2RIbUsnSw_335_341.npy
#   inflating: zxB4dFJhHR8_1_9.npy
#   inflating: zzit5b_-ukg_5_20.npy

# %%
import zipfile

archive = zipfile.ZipFile('/content/drive/MyDrive/MP/Gloabal_GA_Features.zip')

for file in archive.namelist():
        archive.extract(file, 'destination')

# %%
# !unzip '/content/drive/MyDrive/MP/motion_features1.zip'

# %%
# !unzip '/content/drive/MyDrive/MP/local_features1.zip'

# %%
#Prepare training and validation data
df = pd.read_csv('/content/drive/MyDrive/MP/data.csv')
train_ids = videoIDs[:1870]
train_split = 0.85
train_list=[]
vocab_list=[]
for i in range(len(train_ids)):
  df_temp=df.loc[df['VideoID']==train_ids[i]]
  for _, row in df_temp.iterrows():
    caption = "<bos> " + row['Description'] + " <eos>"
    if len(caption.split()) > 10 or len(caption.split()) < 6:
        continue
    else:
        train_list.append([caption, train_ids[i]])
random.shuffle(train_list)
training_list = train_list[:int(len(train_list)*train_split)]
validation_list = train_list[int(len(train_list)*train_split):]

for train in training_list:
    vocab_list.append(train[0])
tokenizer = Tokenizer(num_words=1500)
tokenizer.fit_on_texts(vocab_list)

# %%
x_data_global={}
for i,id in enumerate(train_ids):
  feat_path = '/content/destination/'+id+'.npy'
  features=np.load(feat_path)
  x_data_global[id]=features
print(len(x_data_global))
# Out:
# 1870

# %%
x_data_motion={}
for i,id in enumerate(train_ids):
  feat_path = 'motion_features1/'+id+'.npy'
  features=np.load(feat_path)
  x_data_motion[id]=features
print(len(x_data_motion))
# Out:
# 1870

# %%
x_data_local={}
for i,id in enumerate(train_ids):
  feat_path = 'local_features1/'+id+'.npy'
  features=np.load(feat_path)
  x_data_local[id]=features
print(len(x_data_local))

# %%
import warnings
warnings.filterwarnings("ignore")
tf.get_logger().setLevel('ERROR')

# Hyperparameters
time_steps_encoder=28
num_encoder_tokens=2048
latent_dim=512
time_steps_decoder=10
num_decoder_tokens=1500
batch_size=320
epochs = 25
save_model_path = 'model_final'

#Data generator for loading data in batches while training
def load_dataset(training_list):
  encoder_input_data_global = []
  encoder_input_data_motion = []
  encoder_input_data_local = []
  decoder_input_data = []
  decoder_target_data = []
  train_videoIDs = []
  videoSeq = []
  for idx, cap in enumerate(training_list):
    caption = cap[0]
    train_videoIDs.append(cap[1])
    videoSeq.append(caption)
  train_sequences = tokenizer.texts_to_sequences(videoSeq)
  train_sequences = np.array(train_sequences)
  train_sequences = pad_sequences(train_sequences, padding='post', truncating='post',
                                  maxlen=10)
  file_size = len(train_sequences)
  n = 0
  for i in range(epochs): #epochs
    for idx in range(0, file_size):
      n += 1
      encoder_input_data_global.append(x_data_global[train_videoIDs[idx]])
      encoder_input_data_motion.append(x_data_motion[train_videoIDs[idx]])
      encoder_input_data_local.append(x_data_local[train_videoIDs[idx]])
      y = tf.keras.utils.to_categorical(train_sequences[idx], 1500)
      decoder_input_data.append(y[:-1])
      decoder_target_data.append(y[1:])
      if n == batch_size: #batch size
        encoder_input_global = np.array(encoder_input_data_global)
        encoder_input_motion = np.array(encoder_input_data_motion)
        encoder_input_local = np.array(encoder_input_data_local)
        decoder_input = np.array(decoder_input_data)
        decoder_target = np.array(decoder_target_data)
        encoder_input_data_global = []
        encoder_input_data_motion = []
        encoder_input_data_local = []
        decoder_input_data = []
        decoder_target_data = []
        n = 0
        yield ([encoder_input_global, encoder_input_motion, encoder_input_local, decoder_input], decoder_target)

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras import backend as K
class attention(tf.keras.layers.Layer):
    
    def __init__(self, return_sequences=True,**kwargs):
        self.return_sequences = return_sequences
        super(attention,self).__init__()

    def get_config(self):
      config = super().get_config().copy()
      config.update({
          'return_sequences': self.return_sequences 
      })
      return config
        
    def build(self, input_shape):
        
        self.W=self.add_weight(name="att_weight", shape=(input_shape[-1],1),
                               initializer="normal")
        self.b=self.add_weight(name="att_bias", shape=(input_shape[1],1),
                               initializer="zeros")
        
        super(attention,self).build(input_shape)
        
    def call(self, x):
        
        e = K.tanh(K.dot(x,self.W)+self.b)
        a = K.softmax(e, axis=1)
        output = x*a
        
        if self.return_sequences:
            return output
        
        return K.sum(output, axis=1)

# %%
# Model training
def train_model():
  encoder_inputs_global = tf.keras.layers.Input(shape=(time_steps_encoder, 2048), name="encoder_inputs_global")
  encoder_inputs_motion = tf.keras.layers.Input(shape=(time_steps_encoder, 4096), name="encoder_inputs_motion")
  encoder_inputs_local = tf.keras.layers.Input(shape=(time_steps_encoder, 4096), name="encoder_inputs_local")
  #add concat layer
  encoder_inputs = tf.keras.layers.Concatenate(axis=2)([encoder_inputs_global, encoder_inputs_motion, encoder_inputs_local])

  encoder = tf.keras.layers.GRU(latent_dim, return_state=True, return_sequences=True, name='encoder_gru')
  # _, state_h = encoder(encoder_inputs)

  encoder_seq_output, state_h = encoder(encoder_inputs)
  attention_output = attention(return_sequences=False)(encoder_seq_output)
  # encoder = tf.keras.layers.GRU(latent_dim, return_state=True, return_sequences=True, name='encoder_lstm')
  # _, state_h_1 = encoder(attention_output)
  encoder_states = [attention_output]

  # encoder_states = [state_h]

  decoder_inputs = tf.keras.layers.Input(shape=(time_steps_decoder, num_decoder_tokens), name="decoder_inputs")
  decoder_gru = tf.keras.layers.GRU(latent_dim, return_sequences=True, return_state=True, name='decoder_gru')
  decoder_outputs, _ = decoder_gru(decoder_inputs, initial_state=encoder_states)
  decoder_outputs = tf.keras.layers.Dropout(0.3)(decoder_outputs)
  decoder_dense = tf.keras.layers.Dense(num_decoder_tokens, activation='sigmoid', name='decoder_sigmoid')
  decoder_outputs = decoder_dense(decoder_outputs)

  model = tf.keras.models.Model([encoder_inputs_global,encoder_inputs_motion, encoder_inputs_local, decoder_inputs], decoder_outputs)
  # model.summary()
  # training_list, validation_list = preprocessing()

  train = load_dataset(training_list)
  valid = load_dataset(validation_list)

  # early_stopping = EarlyStopping(monitor='val_loss', patience=4, verbose=1, mode='min')

  # Run training
  opt = tf.keras.optimizers.Adam(learning_rate=0.0003)
  reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",
                                                factor=0.1, patience=5, verbose=1,
                                                mode="auto")
  model.compile(metrics=['accuracy'], optimizer=opt, loss='categorical_crossentropy')

  validation_steps = len(validation_list)//batch_size
  steps_per_epoch = len(training_list)//batch_size

  history=model.fit(train, validation_data=valid, validation_steps=validation_steps,
            epochs=25, steps_per_epoch=steps_per_epoch,
            callbacks=[reduce_lr])

  if not os.path.exists(save_model_path):
      os.makedirs(save_model_path)

  encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)
  decoder_state_input_h = tf.keras.layers.Input(shape=(latent_dim,))
  # decoder_state_input_c = tf.keras.layers.Input(shape=(latent_dim,))
  decoder_states_inputs = [decoder_state_input_h]
  decoder_outputs, state_h = decoder_gru(
      decoder_inputs, initial_state=decoder_states_inputs)
  decoder_states = [state_h]
  decoder_outputs = decoder_dense(decoder_outputs)
  decoder_model = tf.keras.models.Model(
      [decoder_inputs] + decoder_states_inputs,
      [decoder_outputs] + decoder_states)
  # encoder_model.summary()
  # decoder_model.summary()

  # saving the models
  encoder_model.save(os.path.join(save_model_path, 'encoder_model.h5'))
  decoder_model.save_weights(os.path.join(save_model_path, 'decoder_model_weights.h5'))
  with open(os.path.join(save_model_path, 'tokenizer' + str(num_decoder_tokens)), 'wb') as file:
      joblib.dump(tokenizer, file)
  
  return history

history = train_model()
# Out:
# Epoch 1/25
# 152/152 [==============================] - 129s 773ms/step - loss: 3.5668 - accuracy: 0.3830 - val_loss: 2.9815 - val_accuracy: 0.4610 - lr: 3.0000e-04
# Epoch 2/25
# 152/152 [==============================] - 110s 722ms/step - loss: 2.8397 - accuracy: 0.4954 - val_loss: 2.5961 - val_accuracy: 0.5413 - lr: 3.0000e-04
# Epoch 3/25
# 152/152 [==============================] - 115s 760ms/step - loss: 2.4662 - accuracy: 0.5624 - val_loss: 2.2824 - val_accuracy: 0.5854 - lr: 3.0000e-04
# Epoch 4/25
# 152/152 [==============================] - 109s 719ms/step - loss: 2.1878 - accuracy: 0.5964 - val_loss: 2.0505 - val_accuracy: 0.6177 - lr: 3.0000e-04
# Epoch 5/25
# 152/152 [==============================] - 108s 710ms/step - loss: 1.9805 - accuracy: 0.6218 - val_loss: 1.8788 - val_accuracy: 0.6372 - lr: 3.0000e-04
# Epoch 6/25
# 152/152 [==============================] - 110s 722ms/step - loss: 1.8225 - accuracy: 0.6406 - val_loss: 1.7454 - val_accuracy: 0.6534 - lr: 3.0000e-04
# Epoch 7/25
# 152/152 [==============================] - 114s 754ms/step - loss: 1.6975 - accuracy: 0.6565 - val_loss: 1.6406 - val_accuracy: 0.6679 - lr: 3.0000e-04
# Epoch 8/25
# 152/152 [==============================] - 109s 717ms/step - loss: 1.5972 - accuracy: 0.6693 - val_loss: 1.5549 - val_accuracy: 0.6793 - lr: 3.0000e-04
# Epoch 9/25
# 152/152 [==============================] - 115s 759ms/step - loss: 1.5147 - accuracy: 0.6807 - val_loss: 1.4877 - val_accuracy: 0.6877 - lr: 3.0000e-04
# Epoch 10/25
# 152/152 [==============================] - 115s 758ms/step - loss: 1.4480 - accuracy: 0.6897 - val_loss: 1.4321 - val_accuracy: 0.6955 - lr: 3.0000e-04
# Epoch 11/25
# 152/152 [==============================] - 114s 751ms/step - loss: 1.3917 - accuracy: 0.6977 - val_loss: 1.3894 - val_accuracy: 0.7009 - lr: 3.0000e-04
# Epoch 12/25
# 152/152 [==============================] - 109s 715ms/step - loss: 1.3462 - accuracy: 0.7037 - val_loss: 1.3585 - val_accuracy: 0.7041 - lr: 3.0000e-04
# Epoch 13/25
# 152/152 [==============================] - 110s 725ms/step - loss: 1.3069 - accuracy: 0.7091 - val_loss: 1.3305 - val_accuracy: 0.7076 - lr: 3.0000e-04
# Epoch 14/25
# 152/152 [==============================] - 114s 750ms/step - loss: 1.2749 - accuracy: 0.7133 - val_loss: 1.3079 - val_accuracy: 0.7104 - lr: 3.0000e-04
# Epoch 15/25
# 152/152 [==============================] - 113s 746ms/step - loss: 1.2474 - accuracy: 0.7163 - val_loss: 1.2896 - val_accuracy: 0.7134 - lr: 3.0000e-04
# Epoch 16/25
# 152/152 [==============================] - 113s 747ms/step - loss: 1.2211 - accuracy: 0.7202 - val_loss: 1.2684 - val_accuracy: 0.7167 - lr: 3.0000e-04
# Epoch 17/25
# 152/152 [==============================] - 108s 713ms/step - loss: 1.1986 - accuracy: 0.7222 - val_loss: 1.2542 - val_accuracy: 0.7179 - lr: 3.0000e-04
# Epoch 18/25
# 152/152 [==============================] - 109s 718ms/step - loss: 1.1785 - accuracy: 0.7252 - val_loss: 1.2397 - val_accuracy: 0.7202 - lr: 3.0000e-04
# Epoch 19/25
# 152/152 [==============================] - 108s 714ms/step - loss: 1.1606 - accuracy: 0.7269 - val_loss: 1.2284 - val_accuracy: 0.7216 - lr: 3.0000e-04
# Epoch 20/25
# 152/152 [==============================] - 113s 742ms/step - loss: 1.1430 - accuracy: 0.7292 - val_loss: 1.2178 - val_accuracy: 0.7223 - lr: 3.0000e-04
# Epoch 21/25
# 152/152 [==============================] - 108s 712ms/step - loss: 1.1281 - accuracy: 0.7315 - val_loss: 1.2079 - val_accuracy: 0.7241 - lr: 3.0000e-04
# Epoch 22/25
# 152/152 [==============================] - 109s 720ms/step - loss: 1.1138 - accuracy: 0.7329 - val_loss: 1.1997 - val_accuracy: 0.7246 - lr: 3.0000e-04
# Epoch 23/25
# 152/152 [==============================] - 114s 751ms/step - loss: 1.1007 - accuracy: 0.7347 - val_loss: 1.1939 - val_accuracy: 0.7255 - lr: 3.0000e-04
# Epoch 24/25
# 152/152 [==============================] - 112s 740ms/step - loss: 1.0884 - accuracy: 0.7363 - val_loss: 1.1879 - val_accuracy: 0.7257 - lr: 3.0000e-04
# Epoch 25/25
# 152/152 [==============================] - 107s 705ms/step - loss: 1.0767 - accuracy: 0.7374 - val_loss: 1.1849 - val_accuracy: 0.7264 - lr: 3.0000e-04

# %%
from google.colab import files
files.download('/content/model_final')

# %%
	# !zip -r /content/model_final.zip /content/model_final
# Out:
#   adding: content/model_final/ (stored 0%)
#   adding: content/model_final/encoder_model.h5 (deflated 8%)
#   adding: content/model_final/decoder_model_weights.h5 (deflated 7%)
#   adding: content/model_final/tokenizer1500 (deflated 52%)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.grid(True)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy vs No. of Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.grid(True)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs No. of Epochs')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
file = open('/content/drive/MyDrive/MP/test_data.txt','w')
for id in videoIDs[-100:]:
  print(id,file=file)
file.close()

# %%
# !unzip 'drive/MyDrive/IT416/model_gru.zip'

# %%
# class to perform inference on all test files and save as test_output.txt
class Video2Text(object):
    ''' Initialize the parameters for the model '''
    def __init__(self):
        self.latent_dim = 512
        self.num_encoder_tokens = 2048
        self.num_decoder_tokens = 1500
        self.time_steps_encoder = 28
        self.time_steps_decoder = None
        self.max_probability = -1

        # processed data
        self.encoder_input_data = []
        self.decoder_input_data = []
        self.decoder_target_data = []
        self.tokenizer = None

        # models
        self.encoder_model = None
        self.decoder_model = None
        self.inf_encoder_model = None
        self.inf_decoder_model = None
        self.save_model_path = 'model_final'
        self.test_path_global = 'destination'
        self.test_path_motion = 'motion_features1'
        self.test_path_local = 'local_features1'

    def load_inference_models(self):
        # load tokenizer
        with open(os.path.join(self.save_model_path, 'tokenizer' + str(self.num_decoder_tokens)), 'rb') as file:
            self.tokenizer = joblib.load(file)

        # inference encoder model
        self.inf_encoder_model = tf.keras.models.load_model(os.path.join(self.save_model_path, 'encoder_model.h5'),custom_objects={'attention':attention})

        # inference decoder model
        decoder_inputs = tf.keras.layers.Input(shape=(None, self.num_decoder_tokens))
        decoder_dense = tf.keras.layers.Dense(self.num_decoder_tokens, activation='softmax')
        
        decoder_gru = tf.keras.layers.GRU(self.latent_dim, return_sequences=True, return_state=True)
        decoder_state_input_h = tf.keras.layers.Input(shape=(self.latent_dim,))
        # decoder_state_input_c = tf.keras.layers.Input(shape=(self.latent_dim,))
        decoder_states_inputs = [decoder_state_input_h]
        decoder_outputs, state_h = decoder_gru(decoder_inputs, initial_state=decoder_states_inputs)
        decoder_states = [state_h]
        decoder_outputs = decoder_dense(decoder_outputs)
        self.inf_decoder_model = tf.keras.models.Model(
            [decoder_inputs] + decoder_states_inputs,
            [decoder_outputs] + decoder_states)

        self.inf_decoder_model.load_weights(os.path.join(self.save_model_path, 'decoder_model_weights.h5'))
        print('Loaded Inference Model')

    
    def index_to_word(self):
        # inverts word tokenizer
        index_to_word = {value: key for key, value in self.tokenizer.word_index.items()}
        return index_to_word
    
    def greedy_search(self, f):
        """
        :param f: the loaded numpy array after creating videos to frames and extracting features
        :return: the final sentence which has been predicted greedily
        """
        inv_map = self.index_to_word()
        states_value = self.inf_encoder_model.predict(f.reshape(-1, 28, 10240))
        states_value = np.array(states_value).reshape((1, 512))
        target_seq = np.zeros((1, 1, 1500))
        sentence = ''
        target_seq[0, 0, self.tokenizer.word_index['bos']] = 1
        for i in range(15):
            output_tokens, h = self.inf_decoder_model.predict([target_seq] + [states_value])
            states_value = [h]
            output_tokens = output_tokens.reshape(self.num_decoder_tokens)
            y_hat = np.argmax(output_tokens)
            if y_hat == 0:
                continue
            if inv_map[y_hat] is None:
                break
            else:
                sentence = sentence + inv_map[y_hat] + ' '
                target_seq = np.zeros((1, 1, 1500))
                target_seq[0, 0, y_hat] = 1
        return ' '.join(sentence.split()[:-1])

    def decode_sequence2bs(self, input_seq):
        states_value = self.inf_encoder_model.predict(input_seq)
        target_seq = np.zeros((1, 1, self.num_decoder_tokens))
        target_seq[0, 0, self.tokenizer.word_index['bos']] = 1
        self.beam_search(target_seq, states_value,[],[],0)
        return decode_seq

    def beam_search(self, target_seq, states_value, prob,  path, lens):
        global decode_seq
        node = 2
        # target_seq = np.array(target_seq)
        # states_value = np.array(states_value)
        states_value = np.array(states_value).reshape((1, 512))
        output_tokens, h = self.inf_decoder_model.predict(
            [target_seq] + [states_value])
        output_tokens = output_tokens.reshape((self.num_decoder_tokens))
        sampled_token_index = output_tokens.argsort()[-node:][::-1]
        states_value = [h]
        for i in range(node):
            if sampled_token_index[i] == 0:
                sampled_char = ''
            else:
                sampled_char = list(self.tokenizer.word_index.keys())[list(self.tokenizer.word_index.values()).index(sampled_token_index[i])]
            MAX_LEN = 10
            if(sampled_char != 'eos' and lens <= MAX_LEN):
                p = output_tokens[sampled_token_index[i]]
                if(sampled_char == ''):
                    p = 1
                prob_new = list(prob)
                prob_new.append(p)
                path_new = list(path)
                path_new.append(sampled_char)
                target_seq = np.zeros((1, 1, self.num_decoder_tokens))
                target_seq[0, 0, sampled_token_index[i]] = 1.
                self.beam_search(target_seq, states_value, prob_new, path_new, lens+1)
            else:
                p = output_tokens[sampled_token_index[i]]
                prob_new = list(prob)
                prob_new.append(p)
                p = functools.reduce(operator.mul, prob_new, 1)
                if(p > self.max_probability):
                    decode_seq = path
                    self.max_probability = p

    def decoded_sentence_tuning(self, decoded_sentence):
        decode_str = []
        filter_string = ['bos', 'eos']
        unigram = {}
        last_string = ""
        for idx2, c in enumerate(decoded_sentence):
            if c in unigram:
                unigram[c] += 1
            else:
                unigram[c] = 1
            if(last_string == c and idx2 > 0):
                continue
            if c in filter_string:
                continue
            if len(c) > 0:
                decode_str.append(c)
            if idx2 > 0:
                last_string = c
        return decode_str

    def get_test_data(self, path_global, path_motion, path_local):
        X_test = []
        X_test_filename = []
        with open('/content/drive/MyDrive/MP/test_data.txt') as testing_file:
            lines = testing_file.readlines()
            for filename in lines:
                filename = filename.strip()
                f1 = np.load(os.path.join(path_global , filename + '.npy'))
                f2 = np.load(os.path.join(path_motion , filename + '.npy'))
                f3 = np.load(os.path.join(path_motion , filename + '.npy'))
                X_test.append(np.concatenate((f1,f2,f3),axis=1))
                X_test_filename.append(filename)
            X_test = np.array(X_test)
            print('X_test.shape:',X_test.shape)
        return X_test, X_test_filename

    def test(self):
        X_test, X_test_filename = self.get_test_data(os.path.join(self.test_path_global),os.path.join(self.test_path_motion),os.path.join(self.test_path_local))
        print(len(X_test), len(X_test_filename))
        # generate inference test outputs
        with open(os.path.join(self.save_model_path, 'test_output.txt'), 'w') as file:
            for idx, x in enumerate(X_test): 
                file.write(X_test_filename[idx]+',')
                # decoded_sentence = self.decode_sequence2bs(x.reshape(-1, 28, 10240))
                # decode_str = self.decoded_sentence_tuning(decoded_sentence)
                # for d in decode_str:
                #     file.write(d + ' ')
              
                decoded_sentence = self.greedy_search(x.reshape(-1, 28, 10240))
                file.write(decoded_sentence)

                file.write('\n')
                # re-init max prob
                self.max_probability = -1

# %%
c = Video2Text()
c.load_inference_models()
c.test()

# %%
from keras.utils.vis_utils import plot_model
encoder_inputs_global = tf.keras.layers.Input(shape=(time_steps_encoder, 2048), name="encoder_inputs_global")
encoder_inputs_motion = tf.keras.layers.Input(shape=(time_steps_encoder, 4096), name="encoder_inputs_motion")
encoder_inputs_local = tf.keras.layers.Input(shape=(time_steps_encoder, 4096), name="encoder_inputs_local")
#add concat layer
encoder_inputs = tf.keras.layers.Concatenate(axis=2)([encoder_inputs_global, encoder_inputs_motion, encoder_inputs_local])

encoder = tf.keras.layers.GRU(latent_dim, return_state=True, return_sequences=True, name='encoder_gru')
# _, state_h = encoder(encoder_inputs)

encoder_seq_output, state_h = encoder(encoder_inputs)
attention_output = attention(return_sequences=False)(encoder_seq_output)
# encoder = tf.keras.layers.GRU(latent_dim, return_state=True, return_sequences=True, name='encoder_lstm')
# _, state_h_1 = encoder(attention_output)
encoder_states = [attention_output]

# encoder_states = [state_h]

decoder_inputs = tf.keras.layers.Input(shape=(time_steps_decoder, num_decoder_tokens), name="decoder_inputs")
decoder_gru = tf.keras.layers.GRU(latent_dim, return_sequences=True, return_state=True, name='decoder_gru')
decoder_outputs, _ = decoder_gru(decoder_inputs, initial_state=encoder_states)
decoder_outputs = tf.keras.layers.Dropout(0.3)(decoder_outputs)
decoder_dense = tf.keras.layers.Dense(num_decoder_tokens, activation='sigmoid', name='decoder_sigmoid')
decoder_outputs = decoder_dense(decoder_outputs)

model = tf.keras.models.Model([encoder_inputs_global,encoder_inputs_motion, encoder_inputs_local, decoder_inputs], decoder_outputs)
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ##Evaluation Metrics
#
# Coco eval

# %%
#Prepare training and validation data
df = pd.read_csv('/content/drive/MyDrive/MP/data.csv')
test_ids = videoIDs[-100:]

references_list=[]
ref_dict={'annotations':[]}
for i in range(len(test_ids)):
  df_temp=df.loc[df['VideoID']==test_ids[i]]
  references=[]
  for _, row in df_temp.iterrows():
    reference = row['Description'].split()
    ref_dict['annotations'].append({u'video_id':i,u'caption':row['Description']})
    references.append(reference)
  references_list.append(references)

print(ref_dict)

# %%
hypotheses = []
count=0
hyp_dict={'annotations':[]}
with open('/content/model_final/test_output.txt','r') as file:
  for line in file:
    vid = line.split(',')[0]
    hyp = line.split(',')[1]
    hyp=hyp.split('\n')[0]
    hypotheses.append(hyp)
    hyp_dict['annotations'].append({u'video_id':count,u'caption':hyp})
    count=count+1

print(hyp_dict)

# %%
# !pip install "git+https://github.com/salaniz/pycocoevalcap.git"

# %%
from pycocoevalcap.tokenizer.ptbtokenizer import PTBTokenizer
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.meteor.meteor import Meteor
from pycocoevalcap.rouge.rouge import Rouge
from pycocoevalcap.cider.cider import Cider

class COCOEvalCap:
    def __init__(self,images,gts,res):
        self.evalImgs = []
        self.eval = {}
        self.imgToEval = {}
        self.params = {'video_id': images}
        self.gts = gts
        self.res = res

    def evaluate(self):
        imgIds = self.params['video_id']
        gts = self.gts
        res = self.res

        # =================================================
        # Set up scorers
        # =================================================
        print('tokenization...')
        tokenizer = PTBTokenizer()
        gts  = tokenizer.tokenize(gts)
        res = tokenizer.tokenize(res)

        # =================================================
        # Set up scorers
        # =================================================
        print('setting up scorers...')
        scorers = [
            (Bleu(4), ["Bleu_1", "Bleu_2", "Bleu_3", "Bleu_4"]),
            (Meteor(),"METEOR"),
            (Rouge(), "ROUGE_L"),
            (Cider(), "CIDEr")
        ]

        # =================================================
        # Compute scores
        # =================================================
        eval = {}
        for scorer, method in scorers:
            print('computing %s score...'%(scorer.method()))
            score, scores = scorer.compute_score(gts, res)
            if type(method) == list:
                for sc, scs, m in zip(score, scores, method):
                    self.setEval(sc, m)
                    self.setImgToEvalImgs(scs, imgIds, m)
                    print("%s: %0.3f"%(m, sc))
            else:
                self.setEval(score, method)
                self.setImgToEvalImgs(scores, imgIds, method)
                print("%s: %0.3f"%(method, score))
        self.setEvalImgs()

    def setEval(self, score, method):
        self.eval[method] = score

    def setImgToEvalImgs(self, scores, imgIds, method):
        for imgId, score in zip(imgIds, scores):
            if not imgId in self.imgToEval:
                self.imgToEval[imgId] = {}
                self.imgToEval[imgId]["video_id"] = imgId
            self.imgToEval[imgId][method] = score

    def setEvalImgs(self):
        self.evalImgs = [eval for imgId, eval in self.imgToEval.items()]

def calculate_metrics(rng,datasetGTS,datasetRES):
    imgIds = rng
    gts = {}
    res = {}

    imgToAnnsGTS = {ann['video_id']: [] for ann in datasetGTS['annotations']}
    for ann in datasetGTS['annotations']:
        imgToAnnsGTS[ann['video_id']] += [ann]

    imgToAnnsRES = {ann['video_id']: [] for ann in datasetRES['annotations']}
    for ann in datasetRES['annotations']:
        imgToAnnsRES[ann['video_id']] += [ann]

    for imgId in imgIds:
        gts[imgId] = imgToAnnsGTS[imgId]
        res[imgId] = imgToAnnsRES[imgId]

    evalObj = COCOEvalCap(imgIds,gts,res)
    evalObj.evaluate()
    return evalObj.eval

rng = range(100)
print(calculate_metrics(rng,ref_dict,hyp_dict))
